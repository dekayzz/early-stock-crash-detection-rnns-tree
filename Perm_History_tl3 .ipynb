# %% [markdown]
# # Library

# %%
# Import standard data processing libraries
import pandas as pd
import numpy as np
import random
import os

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# Set log level
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tempfile
import warnings
from sklearn.exceptions import ConvergenceWarning
import pickle
import re

# Filter warnings
warnings.simplefilter('ignore', ConvergenceWarning)
warnings.filterwarnings('ignore', category=UserWarning, module='xgboost')

# Import visualization library
import matplotlib.pyplot as plt

# Import Machine Learning and Data Preprocessing libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import KNNImputer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import (precision_recall_curve, average_precision_score, 
                             confusion_matrix, accuracy_score, precision_score, 
                             recall_score, f1_score, balanced_accuracy_score)
from imblearn.combine import SMOTEENN
from sklearn.utils.class_weight import compute_class_weight

# Import Deep Learning libraries - Keras & TensorFlow
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import (Dense, Input, GlobalMaxPooling1D, LSTM, GRU, 
                                     Bidirectional, Dropout, BatchNormalization, SimpleRNN)
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.metrics import BinaryAccuracy, AUC
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.layers import Activation

# %% [markdown]
# # Functions

# %%
# Fungsi Setiap Arsiterktur
# Model GRU
def make_model_GRU(look_back, n_features, units, learning_rate, num_layers, dropout_rate=0.2):
    model = Sequential()
    # Menambahkan layer GRU
    for i in range(num_layers):
        return_sequences = i < num_layers - 1  # True untuk layer bukan terakhir
        model.add(GRU(
            units=units,
            activation='relu',
            input_shape=(look_back, n_features),
            return_sequences=return_sequences,
            kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            recurrent_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            bias_regularizer=l1_l2(l1=1e-5, l2=1e-4)
        ))
        model.add(Dropout(dropout_rate))

    # Menambahkan layer Dense
    model.add(Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))
    model.add(Dense(1, activation='sigmoid'))

    # Mengonfigurasi optimizer
    adam_optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam_optimizer, loss='binary_crossentropy', metrics=METRICS)
    return model

# Model LSTM
def make_model_LSTM(look_back, n_features, units, learning_rate, num_layers, dropout_rate=0.2):
    model = Sequential()
    # Menambahkan layer
    for i in range(num_layers):
        return_sequences = i < num_layers - 1  # True untuk layer bukan terakhir
        model.add(LSTM(
            units=units,
            activation='relu',
            input_shape=(look_back, n_features),
            return_sequences=return_sequences,
            kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            recurrent_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            bias_regularizer=l1_l2(l1=1e-5, l2=1e-4)
        ))
        model.add(Dropout(dropout_rate))

    # Menambahkan layer Dense
    model.add(Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))
    model.add(Dense(1, activation='sigmoid'))

    # Mengonfigurasi optimizer
    adam_optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam_optimizer, loss='binary_crossentropy', metrics=METRICS)
    return model

# Model RNN
def make_model_RNN(look_back, n_features, units, learning_rate, num_layers, dropout_rate=0.2):
    model = Sequential()
    # Menambahkan layer
    for i in range(num_layers):
        return_sequences = i < num_layers - 1  # True untuk layer bukan terakhir
        model.add(SimpleRNN(
            units=units,
            activation='relu',
            input_shape=(look_back, n_features),
            return_sequences=return_sequences,
            kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            recurrent_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            bias_regularizer=l1_l2(l1=1e-5, l2=1e-4)
        ))
        model.add(Dropout(dropout_rate))

    # Menambahkan layer Dense
    model.add(Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))
    model.add(Dense(1, activation='sigmoid'))

    # Mengonfigurasi optimizer
    adam_optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam_optimizer, loss='binary_crossentropy', metrics=METRICS)
    return model

# Fungsi split data
def split_data(data, start, end):
    return data[(data.index >= start) & (data.index <= end)]

# Fungsi untuk mengubah fitur X menjadi format dengan lag untuk RNN, GRU, LSTM
def create_lagged_features_lstm(X, look_back):
    """
    Creates lagged features for LSTM, GRU, RNN
    
    Args:
    X (array-like): The input features.
    look_back (int): The number of lag days.

    Returns:
    numpy.array: Transformed features with lag.
    """
    X_lagged = []
    for i in range(look_back, len(X)):
        X_lagged.append(X[i-look_back:i, :])
    return np.array(X_lagged)

# Metrik PRC AUC
METRICS = [
    'accuracy',
    AUC(name='prc', curve='PR'),
]

# Time Steps
look_back = 5

# Fungsi untuk mengubah fitur X menjadi format dengan lag untuk random forest dan xgboost
def create_lagged_features(X, look_back):
    X_lagged = []
    for i in range(look_back, len(X)):
        # Convert the DataFrame slice to a NumPy array before flattening
        X_lagged.append(X.iloc[i-look_back:i].to_numpy().flatten())
    return np.array(X_lagged)

# Extrack nama path
def extract_params_from_path(model_path):
    match = re.search(r'units_(\d+)_dropout_([\d.]+)_iteration', model_path)
    if match:
        units = int(match.group(1))
        dropout_rate = float(match.group(2))
        return units, dropout_rate
    else:
        raise ValueError("Model path tidak sesuai dengan pola yang diharapkan")

# %% [markdown]
# # Data

# %%
# Data Loading
data = pd.read_excel('Data/df.thailand.5persen.xlsx', index_col=0)

# Data Normalization
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# Data Imputation with KNNImputer
imputer = KNNImputer(n_neighbors=5)  # You can change '5' to the desired number of neighbors
data_imputed = imputer.fit_transform(data_scaled)

# Converting imputed data back to DataFrame
data_imputed_df = pd.DataFrame(data_imputed, columns=data.columns, index=data.index)

# Binarize a specific column based on a threshold
# Here, replacing values in the second column based on a 0.5 threshold
data_imputed_df.iloc[:, 1:2] = (data_imputed_df.iloc[:, 1:2] >= 0.5).astype(int)

# Updating the scaled data
data_scaled = data_imputed_df

# Ensuring the index is of datetime type
data_scaled.index = pd.to_datetime(data_scaled.index)

# Extracting the year from the index and creating a 'year' column
data_scaled['year'] = data_scaled.index.year

# Calculating the binary classification proportion per year
proportion_per_year = data_scaled.groupby('year')['idn_crash'].value_counts(normalize=True).unstack()

# Separating the target variable (y) and features (X)
y = data_imputed_df['idn_crash']
X = data_imputed_df.drop('idn_crash', axis=1)

# Uji model pada periode test
X_test = split_data(X, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))
y_test = split_data(y, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))

X_test_lagged = create_lagged_features_lstm(X_test.to_numpy(), look_back)
y_test_lagged = y_test[look_back:]

# Menghitung jumlah fitur
n_features = X_test_lagged.shape[2]

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Evaluation Baseline

# %%
# Dataframe indonesia 2.5% nanti append tiap selesai pemodelan
# Ada kolom  - Model	Negara	TP	FP	TN	FN	HR	FR	BACC	PRC
df_2_5_base = pd.DataFrame(columns=['Model', 'Negara', 'TP', 'FP', 'TN', 'FN', 'HR', 'FR', 'BACC', 'PRC', 'Params'])
df_2_5_base
# Out:
# Empty DataFrame
# Columns: [Model, Negara, TP, FP, TN, FN, HR, FR, BACC, PRC, Params]
# Index: []

# %%
# Simpan prob untuk visualisasi
df_2_5_base_prob = pd.DataFrame(columns=['ProbRNN','ProbLSTM', 'ProbGRU', 'ProbRF', 'ProbXGB'])
df_2_5_base_prob = pd.concat([df_2_5_base_prob, pd.DataFrame(index=y_test_lagged.index)])
df_2_5_base_prob
# Out:
# C:\Users\derik\AppData\Local\Temp\ipykernel_1360\4288287188.py:3: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   df_2_5_base_prob = pd.concat([df_2_5_base_prob, pd.DataFrame(index=y_test_lagged.index)])
#            ProbRNN ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08     NaN      NaN     NaN    NaN     NaN
# 2020-01-09     NaN      NaN     NaN    NaN     NaN
# 2020-01-10     NaN      NaN     NaN    NaN     NaN
# 2020-01-13     NaN      NaN     NaN    NaN     NaN
# 2020-01-14     NaN      NaN     NaN    NaN     NaN
# ...            ...      ...     ...    ...     ...
# 2023-10-26     NaN      NaN     NaN    NaN     NaN
# 2023-10-27     NaN      NaN     NaN    NaN     NaN
# 2023-10-30     NaN      NaN     NaN    NaN     NaN
# 2023-10-31     NaN      NaN     NaN    NaN     NaN
# 2023-11-01     NaN      NaN     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### RNN

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/tl3_rnn_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_RNN(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_RNN(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 471us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 529us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 529us/step
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 561us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 471us/step
# 35/35 [==============================] - 0s 529us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 557us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 529us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 691us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 529us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 532us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 647us/step
# 35/35 [==============================] - 0s 743us/step
# 35/35 [==============================] - 0s 650us/step
# 35/35 [==============================] - 0s 776us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 676us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 821us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 878us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 823us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 676us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 647us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 677us/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 828us/step
# 35/35 [==============================] - 0s 676us/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 742us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 647us/step
# Best Model Index: 0
# 35/35 [==============================] - 0s 588us/step
# Test PRC Score: 0.04289544235924933
# Test Balanced Accuracy Score: 0.5
# False Alarm Rate: 0.0
# Hit Rate: 0.0
# Best Model Path: Model/tl3_rnn_units_64_dropout_0.1_iteration_0.h5
# Confusion Matrix: [[1071    0]
#  [  48    0]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'RNN', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
df_2_5_base
# Out:
# C:\Users\derik\AppData\Local\Temp\ipykernel_1360\1641053047.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
#   Model     Negara TP FP    TN  FN   HR   FR  BACC       PRC  \
# 0   RNN  Indonesia  0  0  1071  48  0.0  0.0   0.5  0.042895
#
#                     Params
# 0  Units: 64, Dropout: 0.1

# %%
# Simpan prob untuk visualisasi
df_2_5_base_prob['ProbRNN'] = predictions_testprob
df_2_5_base_prob
# Out:
#              ProbRNN ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08  0.014676      NaN     NaN    NaN     NaN
# 2020-01-09  0.014443      NaN     NaN    NaN     NaN
# 2020-01-10  0.014348      NaN     NaN    NaN     NaN
# 2020-01-13  0.014376      NaN     NaN    NaN     NaN
# 2020-01-14  0.014354      NaN     NaN    NaN     NaN
# ...              ...      ...     ...    ...     ...
# 2023-10-26  0.014764      NaN     NaN    NaN     NaN
# 2023-10-27  0.014760      NaN     NaN    NaN     NaN
# 2023-10-30  0.014986      NaN     NaN    NaN     NaN
# 2023-10-31  0.014719      NaN     NaN    NaN     NaN
# 2023-11-01  0.014745      NaN     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### LSTM

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/tl3_lstm_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_LSTM(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_LSTM(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 869us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 884us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 995us/step
# 35/35 [==============================] - 0s 831us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 823us/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# Best Model Index: 0
# 35/35 [==============================] - 0s 829us/step
# Test PRC Score: 0.04289544235924933
# Test Balanced Accuracy Score: 0.5
# False Alarm Rate: 0.0
# Hit Rate: 0.0
# Best Model Path: Model/tl3_lstm_units_64_dropout_0.1_iteration_0.h5
# Confusion Matrix: [[1071    0]
#  [  48    0]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'LSTM', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
df_2_5_base
# Out:
#   Model     Negara TP FP    TN  FN   HR   FR  BACC       PRC  \
# 0   RNN  Indonesia  0  0  1071  48  0.0  0.0   0.5  0.042895
# 1  LSTM  Indonesia  0  0  1071  48  0.0  0.0   0.5  0.042895
#
#                     Params
# 0  Units: 64, Dropout: 0.1
# 1  Units: 64, Dropout: 0.1

# %%
# Simpan prob untuk visualisasi
df_2_5_base_prob['ProbLSTM'] = predictions_testprob
df_2_5_base_prob
# Out:
#              ProbRNN  ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08  0.014676  0.096011     NaN    NaN     NaN
# 2020-01-09  0.014443  0.093901     NaN    NaN     NaN
# 2020-01-10  0.014348  0.093303     NaN    NaN     NaN
# 2020-01-13  0.014376  0.093511     NaN    NaN     NaN
# 2020-01-14  0.014354  0.093240     NaN    NaN     NaN
# ...              ...       ...     ...    ...     ...
# 2023-10-26  0.014764  0.091140     NaN    NaN     NaN
# 2023-10-27  0.014760  0.091402     NaN    NaN     NaN
# 2023-10-30  0.014986  0.091092     NaN    NaN     NaN
# 2023-10-31  0.014719  0.091075     NaN    NaN     NaN
# 2023-11-01  0.014745  0.091340     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### GRU

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/tl3_gru_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_GRU(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_GRU(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 823us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 823us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 860us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 897us/step
# 35/35 [==============================] - 0s 782us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 923us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# Best Model Index: 0
# 35/35 [==============================] - 0s 824us/step
# Test PRC Score: 0.04289544235924933
# Test Balanced Accuracy Score: 0.5
# False Alarm Rate: 0.0
# Hit Rate: 0.0
# Best Model Path: Model/tl3_gru_units_64_dropout_0.1_iteration_0.h5
# Confusion Matrix: [[1071    0]
#  [  48    0]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'GRU', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
df_2_5_base
# Out:
#   Model     Negara TP FP    TN  FN   HR   FR  BACC       PRC  \
# 0   RNN  Indonesia  0  0  1071  48  0.0  0.0   0.5  0.042895
# 1  LSTM  Indonesia  0  0  1071  48  0.0  0.0   0.5  0.042895
# 2   GRU  Indonesia  0  0  1071  48  0.0  0.0   0.5  0.042895
#
#                     Params
# 0  Units: 64, Dropout: 0.1
# 1  Units: 64, Dropout: 0.1
# 2  Units: 64, Dropout: 0.1

# %%
# Simpan prob untuk visualisasi
df_2_5_base_prob['ProbGRU'] = predictions_testprob
df_2_5_base_prob
# Out:
#              ProbRNN  ProbLSTM   ProbGRU ProbRF ProbXGB
# 2020-01-08  0.014676  0.096011  0.052469    NaN     NaN
# 2020-01-09  0.014443  0.093901  0.053487    NaN     NaN
# 2020-01-10  0.014348  0.093303  0.052840    NaN     NaN
# 2020-01-13  0.014376  0.093511  0.053104    NaN     NaN
# 2020-01-14  0.014354  0.093240  0.052790    NaN     NaN
# ...              ...       ...       ...    ...     ...
# 2023-10-26  0.014764  0.091140  0.051404    NaN     NaN
# 2023-10-27  0.014760  0.091402  0.052494    NaN     NaN
# 2023-10-30  0.014986  0.091092  0.051848    NaN     NaN
# 2023-10-31  0.014719  0.091075  0.051821    NaN     NaN
# 2023-11-01  0.014745  0.091340  0.052183    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ## Evaluation Smote

# %%
# Dataframe indonesia 2.5% nanti append tiap selesai pemodelan
# Ada kolom  - Model	Negara	TP	FP	TN	FN	HR	FR	BACC	PRC
df_2_5 = pd.DataFrame(columns=['Model', 'Negara', 'TP', 'FP', 'TN', 'FN', 'HR', 'FR', 'BACC', 'PRC', 'Params'])
df_2_5
# Out:
# Empty DataFrame
# Columns: [Model, Negara, TP, FP, TN, FN, HR, FR, BACC, PRC, Params]
# Index: []

# %%
# Simpan prob untuk visualisasi
df_2_5_prob = pd.DataFrame(columns=['ProbRNN','ProbLSTM', 'ProbGRU', 'ProbRF', 'ProbXGB'])
df_2_5_prob = pd.concat([df_2_5_prob, pd.DataFrame(index=y_test_lagged.index)])
df_2_5_prob
# Out:
# C:\Users\derik\AppData\Local\Temp\ipykernel_1360\477191898.py:3: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   df_2_5_prob = pd.concat([df_2_5_prob, pd.DataFrame(index=y_test_lagged.index)])
#            ProbRNN ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08     NaN      NaN     NaN    NaN     NaN
# 2020-01-09     NaN      NaN     NaN    NaN     NaN
# 2020-01-10     NaN      NaN     NaN    NaN     NaN
# 2020-01-13     NaN      NaN     NaN    NaN     NaN
# 2020-01-14     NaN      NaN     NaN    NaN     NaN
# ...            ...      ...     ...    ...     ...
# 2023-10-26     NaN      NaN     NaN    NaN     NaN
# 2023-10-27     NaN      NaN     NaN    NaN     NaN
# 2023-10-30     NaN      NaN     NaN    NaN     NaN
# 2023-10-31     NaN      NaN     NaN    NaN     NaN
# 2023-11-01     NaN      NaN     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### RNN

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/tl3_rnn_smote_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_RNN(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_RNN(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 0s 563us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 529us/step
# 35/35 [==============================] - 0s 529us/step
# 35/35 [==============================] - 0s 529us/step
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 529us/step
# 35/35 [==============================] - 0s 529us/step
# 35/35 [==============================] - 0s 471us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 529us/step
# 35/35 [==============================] - 0s 471us/step
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 529us/step
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 492us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 653us/step
# 35/35 [==============================] - 0s 500us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 529us/step
# 35/35 [==============================] - 0s 617us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 647us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 647us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 529us/step
# 35/35 [==============================] - 0s 865us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 869us/step
# 35/35 [==============================] - 0s 732us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 840us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 816us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 830us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 765us/step
# Best Model Index: 4
# 35/35 [==============================] - 0s 529us/step
# Test PRC Score: 0.08512891801542383
# Test Balanced Accuracy Score: 0.5744631185807656
# False Alarm Rate: 0.017740429505135387
# Hit Rate: 0.16666666666666666
# Best Model Path: Model/tl3_rnn_smote_units_64_dropout_0.1_iteration_4.h5
# Confusion Matrix: [[1052   19]
#  [  40    8]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'RNN', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
df_2_5
# Out:
# C:\Users\derik\AppData\Local\Temp\ipykernel_1360\3206386942.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
#   Model     Negara TP  FP    TN  FN        HR       FR      BACC       PRC  \
# 0   RNN  Indonesia  8  19  1052  40  0.166667  0.01774  0.574463  0.085129
#
#                     Params
# 0  Units: 64, Dropout: 0.1

# %%
# Simpan prob untuk visualisasi
df_2_5_prob['ProbRNN'] = predictions_testprob
df_2_5_prob
# Out:
#              ProbRNN ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08  0.006862      NaN     NaN    NaN     NaN
# 2020-01-09  0.006258      NaN     NaN    NaN     NaN
# 2020-01-10  0.006674      NaN     NaN    NaN     NaN
# 2020-01-13  0.007457      NaN     NaN    NaN     NaN
# 2020-01-14  0.005757      NaN     NaN    NaN     NaN
# ...              ...      ...     ...    ...     ...
# 2023-10-26  0.005534      NaN     NaN    NaN     NaN
# 2023-10-27  0.004865      NaN     NaN    NaN     NaN
# 2023-10-30  0.004792      NaN     NaN    NaN     NaN
# 2023-10-31  0.003339      NaN     NaN    NaN     NaN
# 2023-11-01  0.003307      NaN     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### LSTM

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/tl3_lstm_smote_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_LSTM(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_LSTM(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 827us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 773us/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 829us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 967us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# Best Model Index: 15
# 35/35 [==============================] - 0s 824us/step
# Test PRC Score: 0.08336524958508873
# Test Balanced Accuracy Score: 0.5739962651727357
# False Alarm Rate: 0.018674136321195144
# Hit Rate: 0.16666666666666666
# Best Model Path: Model/tl3_lstm_smote_units_64_dropout_0.2_iteration_5.h5
# Confusion Matrix: [[1051   20]
#  [  40    8]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'LSTM', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
df_2_5
# Out:
#   Model     Negara TP  FP    TN  FN        HR        FR      BACC       PRC  \
# 0   RNN  Indonesia  8  19  1052  40  0.166667  0.017740  0.574463  0.085129
# 1  LSTM  Indonesia  8  20  1051  40  0.166667  0.018674  0.573996  0.083365
#
#                     Params
# 0  Units: 64, Dropout: 0.1
# 1  Units: 64, Dropout: 0.2

# %%
# Simpan prob untuk visualisasi
df_2_5_prob['ProbLSTM'] = predictions_testprob
df_2_5_prob
# Out:
#              ProbRNN  ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08  0.006862  0.000297     NaN    NaN     NaN
# 2020-01-09  0.006258  0.000261     NaN    NaN     NaN
# 2020-01-10  0.006674  0.000323     NaN    NaN     NaN
# 2020-01-13  0.007457  0.000365     NaN    NaN     NaN
# 2020-01-14  0.005757  0.000218     NaN    NaN     NaN
# ...              ...       ...     ...    ...     ...
# 2023-10-26  0.005534  0.000199     NaN    NaN     NaN
# 2023-10-27  0.004865  0.000279     NaN    NaN     NaN
# 2023-10-30  0.004792  0.000214     NaN    NaN     NaN
# 2023-10-31  0.003339  0.000106     NaN    NaN     NaN
# 2023-11-01  0.003307  0.000151     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### GRU

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/tl3_gru_smote_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_GRU(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_GRU(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 897us/step
# 35/35 [==============================] - 0s 825us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 886us/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 823us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 851us/step
# 35/35 [==============================] - 0s 875us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 985us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 853us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# Best Model Index: 12
# 35/35 [==============================] - 0s 1ms/step
# Test PRC Score: 0.09026519817404537
# Test Balanced Accuracy Score: 0.59156162464986
# False Alarm Rate: 0.025210084033613446
# Hit Rate: 0.20833333333333334
# Best Model Path: Model/tl3_gru_smote_units_64_dropout_0.2_iteration_2.h5
# Confusion Matrix: [[1044   27]
#  [  38   10]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'GRU', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
df_2_5
# Out:
#   Model     Negara  TP  FP    TN  FN        HR        FR      BACC       PRC  \
# 0   RNN  Indonesia   8  19  1052  40  0.166667  0.017740  0.574463  0.085129
# 1  LSTM  Indonesia   8  20  1051  40  0.166667  0.018674  0.573996  0.083365
# 2   GRU  Indonesia  10  27  1044  38  0.208333  0.025210  0.591562  0.090265
#
#                     Params
# 0  Units: 64, Dropout: 0.1
# 1  Units: 64, Dropout: 0.2
# 2  Units: 64, Dropout: 0.2

# %%
# Simpan prob untuk visualisasi
df_2_5_prob['ProbGRU'] = predictions_testprob
df_2_5_prob
# Out:
#              ProbRNN  ProbLSTM   ProbGRU ProbRF ProbXGB
# 2020-01-08  0.006862  0.000297  0.145171    NaN     NaN
# 2020-01-09  0.006258  0.000261  0.183334    NaN     NaN
# 2020-01-10  0.006674  0.000323  0.157035    NaN     NaN
# 2020-01-13  0.007457  0.000365  0.165721    NaN     NaN
# 2020-01-14  0.005757  0.000218  0.160437    NaN     NaN
# ...              ...       ...       ...    ...     ...
# 2023-10-26  0.005534  0.000199  0.113458    NaN     NaN
# 2023-10-27  0.004865  0.000279  0.167002    NaN     NaN
# 2023-10-30  0.004792  0.000214  0.116812    NaN     NaN
# 2023-10-31  0.003339  0.000106  0.106626    NaN     NaN
# 2023-11-01  0.003307  0.000151  0.131154    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ## Evalution RF dan XGBoost

# %%
# Latih model pada periode train yang lebih besar
X_train_full = split_data(X, pd.Timestamp('2010-01-01'), pd.Timestamp('2019-12-31'))
y_train_full = split_data(y, pd.Timestamp('2010-01-01'), pd.Timestamp('2019-12-31'))

X_train_full_lagged = create_lagged_features(X_train_full, look_back)
y_train_full_lagged = y_train_full[look_back:]

# Uji model pada periode test
X_test = split_data(X, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))
y_test = split_data(y, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))

X_test_lagged = create_lagged_features(X_test, look_back)
y_test_lagged = y_test[look_back:]

# %% [markdown]
# ### RF

# %%
# Random forest
# Memuat best_params dari file
with open('Model/tl3_rf.pkl', 'rb') as f:
    best_params = pickle.load(f)
model_final = RandomForestClassifier(**best_params, random_state=1501211036)
model_final.fit(X_train_full_lagged, y_train_full_lagged)
predictions_test = model_final.predict(X_test_lagged)
prc_score = average_precision_score(y_test_lagged, predictions_test)
print(f"Test PRC  Score: {prc_score}")
bacc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
print(f"Test Balance Accuracy  Score: {bacc_score}")
cm = confusion_matrix(y_test_lagged, predictions_test)
print(cm)
TP = cm[1, 1]
FN = cm[1, 0]
FP = cm[0, 1]
TN = cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)
print("False Alarm Rate:", FAR)
print("Hit Rate:", HR)

eval_rf = {
    'Metric': ['Test PRC Score', 'Test Balance Accuracy Score', 'False Alarm Rate', 'Hit Rate'],
    'Value': [prc_score, bacc_score, FAR, HR]
}
# Out:
# Test PRC  Score: 0.04105246847552159
# Test Balance Accuracy  Score: 0.475344304388422
# [[505 566]
#  [ 25  23]]
# False Alarm Rate: 0.5284780578898226
# Hit Rate: 0.4791666666666667

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'RF', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': bacc_score, 
    'PRC': prc_score, 
    'Params': f"N Estimators: {best_params['n_estimators']}, Max Depth: {best_params['max_depth']}"
}])

# Menggabungkan dengan DataFrame sebelumnya
df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
df_2_5_base
# Out:
#   Model     Negara  TP   FP    TN  FN        HR        FR      BACC       PRC  \
# 0   RNN  Indonesia   0    0  1071  48  0.000000  0.000000  0.500000  0.042895
# 1  LSTM  Indonesia   0    0  1071  48  0.000000  0.000000  0.500000  0.042895
# 2   GRU  Indonesia   0    0  1071  48  0.000000  0.000000  0.500000  0.042895
# 3    RF  Indonesia  23  566   505  25  0.479167  0.528478  0.475344  0.041052
#
#                              Params
# 0           Units: 64, Dropout: 0.1
# 1           Units: 64, Dropout: 0.1
# 2           Units: 64, Dropout: 0.1
# 3  N Estimators: 400, Max Depth: 20

# %% [markdown]
# ### XGB

# %%
# XGB
with open('Model/tl3_xgb.pkl', 'rb') as f:
    best_params = pickle.load(f)

model_final = XGBClassifier(**best_params, use_label_encoder=False, eval_metric='logloss', random_state=1501211036)
model_final.fit(X_train_full_lagged, y_train_full_lagged)

predictions_test = model_final.predict(X_test_lagged)
prc_score = average_precision_score(y_test_lagged, predictions_test)
print(f"Test PRC  Score: {prc_score}")
bacc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
print(f"Test Balance Accuracy  Score: {bacc_score}")
cm = confusion_matrix(y_test_lagged, predictions_test)
print(cm)
TP = cm[1, 1]
FN = cm[1, 0]
FP = cm[0, 1]
TN = cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)
print("False Alarm Rate:", FAR)
print("Hit Rate:", HR)

eval_xgboost = {
    'Metric': ['Test PRC Score', 'Test Balance Accuracy Score', 'False Alarm Rate', 'Hit Rate'],
    'Value': [prc_score, bacc_score, FAR, HR]
}
# Out:
# Test PRC  Score: 0.04289544235924933
# Test Balance Accuracy  Score: 0.4981325863678805
# [[1067    4]
#  [  48    0]]
# False Alarm Rate: 0.003734827264239029
# Hit Rate: 0.0

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'XGBoost', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': bacc_score, 
    'PRC': prc_score, 
    'Params': f"Learning Rate: {best_params['learning_rate']}, N Estimators: {best_params['n_estimators']}, Max Depth: {best_params['max_depth']}"
}])

# Menggabungkan dengan DataFrame sebelumnya
df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
df_2_5_base
# Out:
#      Model     Negara  TP   FP    TN  FN        HR        FR      BACC  \
# 0      RNN  Indonesia   0    0  1071  48  0.000000  0.000000  0.500000
# 1     LSTM  Indonesia   0    0  1071  48  0.000000  0.000000  0.500000
# 2      GRU  Indonesia   0    0  1071  48  0.000000  0.000000  0.500000
# 3       RF  Indonesia  23  566   505  25  0.479167  0.528478  0.475344
# 4  XGBoost  Indonesia   0    4  1067  48  0.000000  0.003735  0.498133
#
#         PRC                                             Params
# 0  0.042895                            Units: 64, Dropout: 0.1
# 1  0.042895                            Units: 64, Dropout: 0.1
# 2  0.042895                            Units: 64, Dropout: 0.1
# 3  0.041052                   N Estimators: 400, Max Depth: 20
# 4  0.042895  Learning Rate: 0.1, N Estimators: 500, Max Dep...

# %% [markdown]
# ### RF SMOTE

# %%
# Latih model pada periode train yang lebih besar
X_train_full = split_data(X, pd.Timestamp('2010-01-01'), pd.Timestamp('2019-12-31'))
y_train_full = split_data(y, pd.Timestamp('2010-01-01'), pd.Timestamp('2019-12-31'))

# Handling imbalanced with smote
smote_enn = SMOTEENN(random_state=1501211036)
X_train_resampled, y_train_resampled = smote_enn.fit_resample(X_train_full, y_train_full)

X_train_full_lagged = create_lagged_features(X_train_resampled, look_back)
y_train_full_lagged = y_train_resampled[look_back:]

# Uji model pada periode test
X_test = split_data(X, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))
y_test = split_data(y, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))

X_test_lagged = create_lagged_features(X_test, look_back)
y_test_lagged = y_test[look_back:]

# %%
# Random forest
# Memuat best_params dari file
with open('Model/tl3_rf_smote.pkl', 'rb') as f:
    best_params = pickle.load(f)
model_final = RandomForestClassifier(**best_params, random_state=1501211036)
model_final.fit(X_train_full_lagged, y_train_full_lagged)
predictions_test = model_final.predict(X_test_lagged)
prc_score = average_precision_score(y_test_lagged, predictions_test)
print(f"Test PRC  Score: {prc_score}")
bacc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
print(f"Test Balance Accuracy  Score: {bacc_score}")
cm = confusion_matrix(y_test_lagged, predictions_test)
print(cm)
TP = cm[1, 1]
FN = cm[1, 0]
FP = cm[0, 1]
TN = cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)
print("False Alarm Rate:", FAR)
print("Hit Rate:", HR)

eval_rf = {
    'Metric': ['Test PRC Score', 'Test Balance Accuracy Score', 'False Alarm Rate', 'Hit Rate'],
    'Value': [prc_score, bacc_score, FAR, HR]
}
# Out:
# Test PRC  Score: 0.046168453976764966
# Test Balance Accuracy  Score: 0.5085492530345471
# [[1067    4]
#  [  47    1]]
# False Alarm Rate: 0.003734827264239029
# Hit Rate: 0.020833333333333332

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'RF', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': bacc_score, 
    'PRC': prc_score, 
    'Params': f"N Estimators: {best_params['n_estimators']}, Max Depth: {best_params['max_depth']}"
}])

# Menggabungkan dengan DataFrame sebelumnya
df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
df_2_5
# Out:
#   Model     Negara  TP  FP    TN  FN        HR        FR      BACC       PRC  \
# 0   RNN  Indonesia   8  19  1052  40  0.166667  0.017740  0.574463  0.085129
# 1  LSTM  Indonesia   8  20  1051  40  0.166667  0.018674  0.573996  0.083365
# 2   GRU  Indonesia  10  27  1044  38  0.208333  0.025210  0.591562  0.090265
# 3    RF  Indonesia   1   4  1067  47  0.020833  0.003735  0.508549  0.046168
#
#                              Params
# 0           Units: 64, Dropout: 0.1
# 1           Units: 64, Dropout: 0.2
# 2           Units: 64, Dropout: 0.2
# 3  N Estimators: 200, Max Depth: 20

# %% [markdown]
# ### XGB SMOTE

# %%
# XGB
with open('Model/tl3_xgb_smote.pkl', 'rb') as f:
    best_params = pickle.load(f)

model_final = XGBClassifier(**best_params, use_label_encoder=False, eval_metric='logloss', random_state=1501211036)
model_final.fit(X_train_full_lagged, y_train_full_lagged)

predictions_test = model_final.predict(X_test_lagged)
prc_score = average_precision_score(y_test_lagged, predictions_test)
print(f"Test PRC  Score: {prc_score}")
bacc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
print(f"Test Balance Accuracy  Score: {bacc_score}")
cm = confusion_matrix(y_test_lagged, predictions_test)
print(cm)
TP = cm[1, 1]
FN = cm[1, 0]
FP = cm[0, 1]
TN = cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)
print("False Alarm Rate:", FAR)
print("Hit Rate:", HR)

eval_xgboost = {
    'Metric': ['Test PRC Score', 'Test Balance Accuracy Score', 'False Alarm Rate', 'Hit Rate'],
    'Value': [prc_score, bacc_score, FAR, HR]
}
# Out:
# Test PRC  Score: 0.050691406801185265
# Test Balance Accuracy  Score: 0.5386904761904762
# [[1020   51]
#  [  42    6]]
# False Alarm Rate: 0.047619047619047616
# Hit Rate: 0.125

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'XGBoost', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': bacc_score, 
    'PRC': prc_score, 
    'Params': f"Learning Rate: {best_params['learning_rate']}, N Estimators: {best_params['n_estimators']}, Max Depth: {best_params['max_depth']}"
}])

# Menggabungkan dengan DataFrame sebelumnya
df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
df_2_5
# Out:
#      Model     Negara  TP  FP    TN  FN        HR        FR      BACC  \
# 0      RNN  Indonesia   8  19  1052  40  0.166667  0.017740  0.574463
# 1     LSTM  Indonesia   8  20  1051  40  0.166667  0.018674  0.573996
# 2      GRU  Indonesia  10  27  1044  38  0.208333  0.025210  0.591562
# 3       RF  Indonesia   1   4  1067  47  0.020833  0.003735  0.508549
# 4  XGBoost  Indonesia   6  51  1020  42  0.125000  0.047619  0.538690
#
#         PRC                                             Params
# 0  0.085129                            Units: 64, Dropout: 0.1
# 1  0.083365                            Units: 64, Dropout: 0.2
# 2  0.090265                            Units: 64, Dropout: 0.2
# 3  0.046168                   N Estimators: 200, Max Depth: 20
# 4  0.050691  Learning Rate: 0.2, N Estimators: 100, Max Dep...

# %% [markdown]
# # Export

# %%
# Save to excel to folder Output
df_2_5_base.to_excel('Output/tl3_base.xlsx', index=False)
df_2_5_base_prob.to_excel('Output/tl3_base_prob.xlsx', index=True)
df_2_5.to_excel('Output/tl3_smote.xlsx', index=False)
df_2_5_prob.to_excel('Output/tl3_smote_prob.xlsx', index=True)

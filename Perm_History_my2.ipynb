# %% [markdown]
# # Library

# %%
# Import standard data processing libraries
import pandas as pd
import numpy as np
import random
import os

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# Set log level
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tempfile
import warnings
from sklearn.exceptions import ConvergenceWarning
import pickle
import re

# Filter warnings
warnings.simplefilter('ignore', ConvergenceWarning)
warnings.filterwarnings('ignore', category=UserWarning, module='xgboost')

# Import visualization library
import matplotlib.pyplot as plt

# Import Machine Learning and Data Preprocessing libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import KNNImputer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import (precision_recall_curve, average_precision_score, 
                             confusion_matrix, accuracy_score, precision_score, 
                             recall_score, f1_score, balanced_accuracy_score)
from imblearn.combine import SMOTEENN
from sklearn.utils.class_weight import compute_class_weight

# Import Deep Learning libraries - Keras & TensorFlow
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import (Dense, Input, GlobalMaxPooling1D, LSTM, GRU, 
                                     Bidirectional, Dropout, BatchNormalization, SimpleRNN)
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.metrics import BinaryAccuracy, AUC
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.layers import Activation
# Out:
# WARNING:tensorflow:From c:\Users\derik\Anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\derik\AppData\Local\Temp\ipykernel_6048\1027996159.py:41: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %% [markdown]
# # Functions

# %%
# Fungsi Setiap Arsiterktur
# Model GRU
def make_model_GRU(look_back, n_features, units, learning_rate, num_layers, dropout_rate=0.2):
    model = Sequential()
    # Menambahkan layer GRU
    for i in range(num_layers):
        return_sequences = i < num_layers - 1  # True untuk layer bukan terakhir
        model.add(GRU(
            units=units,
            activation='relu',
            input_shape=(look_back, n_features),
            return_sequences=return_sequences,
            kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            recurrent_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            bias_regularizer=l1_l2(l1=1e-5, l2=1e-4)
        ))
        model.add(Dropout(dropout_rate))

    # Menambahkan layer Dense
    model.add(Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))
    model.add(Dense(1, activation='sigmoid'))

    # Mengonfigurasi optimizer
    adam_optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam_optimizer, loss='binary_crossentropy', metrics=METRICS)
    return model

# Model LSTM
def make_model_LSTM(look_back, n_features, units, learning_rate, num_layers, dropout_rate=0.2):
    model = Sequential()
    # Menambahkan layer
    for i in range(num_layers):
        return_sequences = i < num_layers - 1  # True untuk layer bukan terakhir
        model.add(LSTM(
            units=units,
            activation='relu',
            input_shape=(look_back, n_features),
            return_sequences=return_sequences,
            kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            recurrent_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            bias_regularizer=l1_l2(l1=1e-5, l2=1e-4)
        ))
        model.add(Dropout(dropout_rate))

    # Menambahkan layer Dense
    model.add(Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))
    model.add(Dense(1, activation='sigmoid'))

    # Mengonfigurasi optimizer
    adam_optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam_optimizer, loss='binary_crossentropy', metrics=METRICS)
    return model

# Model RNN
def make_model_RNN(look_back, n_features, units, learning_rate, num_layers, dropout_rate=0.2):
    model = Sequential()
    # Menambahkan layer
    for i in range(num_layers):
        return_sequences = i < num_layers - 1  # True untuk layer bukan terakhir
        model.add(SimpleRNN(
            units=units,
            activation='relu',
            input_shape=(look_back, n_features),
            return_sequences=return_sequences,
            kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            recurrent_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            bias_regularizer=l1_l2(l1=1e-5, l2=1e-4)
        ))
        model.add(Dropout(dropout_rate))

    # Menambahkan layer Dense
    model.add(Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))
    model.add(Dense(1, activation='sigmoid'))

    # Mengonfigurasi optimizer
    adam_optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam_optimizer, loss='binary_crossentropy', metrics=METRICS)
    return model

# Fungsi split data
def split_data(data, start, end):
    return data[(data.index >= start) & (data.index <= end)]

# Fungsi untuk mengubah fitur X menjadi format dengan lag untuk RNN, GRU, LSTM
def create_lagged_features_lstm(X, look_back):
    """
    Creates lagged features for LSTM, GRU, RNN
    
    Args:
    X (array-like): The input features.
    look_back (int): The number of lag days.

    Returns:
    numpy.array: Transformed features with lag.
    """
    X_lagged = []
    for i in range(look_back, len(X)):
        X_lagged.append(X[i-look_back:i, :])
    return np.array(X_lagged)

# Metrik PRC AUC
METRICS = [
    'accuracy',
    AUC(name='prc', curve='PR'),
]

# Time Steps
look_back = 5

# Fungsi untuk mengubah fitur X menjadi format dengan lag untuk random forest dan xgboost
def create_lagged_features(X, look_back):
    X_lagged = []
    for i in range(look_back, len(X)):
        # Convert the DataFrame slice to a NumPy array before flattening
        X_lagged.append(X.iloc[i-look_back:i].to_numpy().flatten())
    return np.array(X_lagged)

# Extrack nama path
def extract_params_from_path(model_path):
    match = re.search(r'units_(\d+)_dropout_([\d.]+)_iteration', model_path)
    if match:
        units = int(match.group(1))
        dropout_rate = float(match.group(2))
        return units, dropout_rate
    else:
        raise ValueError("Model path tidak sesuai dengan pola yang diharapkan")

# %% [markdown]
# # Data

# %%
# Data Loading
data = pd.read_excel('Data/df.malaysia.2.5persen.xlsx', index_col=0)

# Data Normalization
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# Data Imputation with KNNImputer
imputer = KNNImputer(n_neighbors=5)  # You can change '5' to the desired number of neighbors
data_imputed = imputer.fit_transform(data_scaled)

# Converting imputed data back to DataFrame
data_imputed_df = pd.DataFrame(data_imputed, columns=data.columns, index=data.index)

# Binarize a specific column based on a threshold
# Here, replacing values in the second column based on a 0.5 threshold
data_imputed_df.iloc[:, 1:2] = (data_imputed_df.iloc[:, 1:2] >= 0.5).astype(int)

# Updating the scaled data
data_scaled = data_imputed_df

# Ensuring the index is of datetime type
data_scaled.index = pd.to_datetime(data_scaled.index)

# Extracting the year from the index and creating a 'year' column
data_scaled['year'] = data_scaled.index.year

# Calculating the binary classification proportion per year
proportion_per_year = data_scaled.groupby('year')['idn_crash'].value_counts(normalize=True).unstack()

# Separating the target variable (y) and features (X)
y = data_imputed_df['idn_crash']
X = data_imputed_df.drop('idn_crash', axis=1)

# Uji model pada periode test
X_test = split_data(X, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))
y_test = split_data(y, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))

X_test_lagged = create_lagged_features_lstm(X_test.to_numpy(), look_back)
y_test_lagged = y_test[look_back:]

# Menghitung jumlah fitur
n_features = X_test_lagged.shape[2]

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Evaluation Baseline

# %%
# Dataframe indonesia 2.5% nanti append tiap selesai pemodelan
# Ada kolom  - Model	Negara	TP	FP	TN	FN	HR	FR	BACC	PRC
df_2_5_base = pd.DataFrame(columns=['Model', 'Negara', 'TP', 'FP', 'TN', 'FN', 'HR', 'FR', 'BACC', 'PRC', 'Params'])
df_2_5_base
# Out:
# Empty DataFrame
# Columns: [Model, Negara, TP, FP, TN, FN, HR, FR, BACC, PRC, Params]
# Index: []

# %%
# Simpan prob untuk visualisasi
df_2_5_base_prob = pd.DataFrame(columns=['ProbRNN','ProbLSTM', 'ProbGRU', 'ProbRF', 'ProbXGB'])
df_2_5_base_prob = pd.concat([df_2_5_base_prob, pd.DataFrame(index=y_test_lagged.index)])
df_2_5_base_prob
# Out:
# C:\Users\derik\AppData\Local\Temp\ipykernel_6048\4288287188.py:3: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   df_2_5_base_prob = pd.concat([df_2_5_base_prob, pd.DataFrame(index=y_test_lagged.index)])
#            ProbRNN ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08     NaN      NaN     NaN    NaN     NaN
# 2020-01-09     NaN      NaN     NaN    NaN     NaN
# 2020-01-10     NaN      NaN     NaN    NaN     NaN
# 2020-01-13     NaN      NaN     NaN    NaN     NaN
# 2020-01-14     NaN      NaN     NaN    NaN     NaN
# ...            ...      ...     ...    ...     ...
# 2023-10-26     NaN      NaN     NaN    NaN     NaN
# 2023-10-27     NaN      NaN     NaN    NaN     NaN
# 2023-10-30     NaN      NaN     NaN    NaN     NaN
# 2023-10-31     NaN      NaN     NaN    NaN     NaN
# 2023-11-01     NaN      NaN     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### RNN

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/my2_rnn_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_RNN(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_RNN(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 5ms/step
# Best Model Index: 0
# 35/35 [==============================] - 1s 5ms/step
# Test PRC Score: 0.032171581769437
# Test Balanced Accuracy Score: 0.5
# False Alarm Rate: 0.0
# Hit Rate: 0.0
# Best Model Path: Model/my2_rnn_units_64_dropout_0.1_iteration_0.h5
# Confusion Matrix: [[1083    0]
#  [  36    0]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'RNN', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
df_2_5_base
# Out:
# C:\Users\derik\AppData\Local\Temp\ipykernel_6048\1641053047.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
#   Model     Negara TP FP    TN  FN   HR   FR  BACC       PRC  \
# 0   RNN  Indonesia  0  0  1083  36  0.0  0.0   0.5  0.032172
#
#                     Params
# 0  Units: 64, Dropout: 0.1

# %%
# Simpan prob untuk visualisasi
df_2_5_base_prob['ProbRNN'] = predictions_testprob
df_2_5_base_prob
# Out:
#                  ProbRNN ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08  4.436488e-25      NaN     NaN    NaN     NaN
# 2020-01-09  4.268890e-25      NaN     NaN    NaN     NaN
# 2020-01-10  4.374143e-25      NaN     NaN    NaN     NaN
# 2020-01-13  4.096371e-25      NaN     NaN    NaN     NaN
# 2020-01-14  4.083702e-25      NaN     NaN    NaN     NaN
# ...                  ...      ...     ...    ...     ...
# 2023-10-26  3.407236e-25      NaN     NaN    NaN     NaN
# 2023-10-27  3.361392e-25      NaN     NaN    NaN     NaN
# 2023-10-30  3.432440e-25      NaN     NaN    NaN     NaN
# 2023-10-31  3.388919e-25      NaN     NaN    NaN     NaN
# 2023-11-01  3.450570e-25      NaN     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### LSTM

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/my2_lstm_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_LSTM(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_LSTM(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 3ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 0s 8ms/step
# 35/35 [==============================] - 1s 8ms/step
# 35/35 [==============================] - 0s 8ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 7ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 8ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 8ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 8ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 7ms/step
# 35/35 [==============================] - 1s 8ms/step
# 35/35 [==============================] - 0s 8ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 7ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 7ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 7ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 8ms/step
# Best Model Index: 0
# 35/35 [==============================] - 1s 6ms/step
# Test PRC Score: 0.032171581769437
# Test Balanced Accuracy Score: 0.5
# False Alarm Rate: 0.0
# Hit Rate: 0.0
# Best Model Path: Model/my2_lstm_units_64_dropout_0.1_iteration_0.h5
# Confusion Matrix: [[1083    0]
#  [  36    0]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'LSTM', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
df_2_5_base
# Out:
#   Model     Negara TP FP    TN  FN   HR   FR  BACC       PRC  \
# 0   RNN  Indonesia  0  0  1083  36  0.0  0.0   0.5  0.032172
# 1  LSTM  Indonesia  0  0  1083  36  0.0  0.0   0.5  0.032172
#
#                     Params
# 0  Units: 64, Dropout: 0.1
# 1  Units: 64, Dropout: 0.1

# %%
# Simpan prob untuk visualisasi
df_2_5_base_prob['ProbLSTM'] = predictions_testprob
df_2_5_base_prob
# Out:
#                  ProbRNN  ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08  4.436488e-25  0.040160     NaN    NaN     NaN
# 2020-01-09  4.268890e-25  0.040203     NaN    NaN     NaN
# 2020-01-10  4.374143e-25  0.040188     NaN    NaN     NaN
# 2020-01-13  4.096371e-25  0.040243     NaN    NaN     NaN
# 2020-01-14  4.083702e-25  0.040239     NaN    NaN     NaN
# ...                  ...       ...     ...    ...     ...
# 2023-10-26  3.407236e-25  0.039552     NaN    NaN     NaN
# 2023-10-27  3.361392e-25  0.039617     NaN    NaN     NaN
# 2023-10-30  3.432440e-25  0.039657     NaN    NaN     NaN
# 2023-10-31  3.388919e-25  0.039633     NaN    NaN     NaN
# 2023-11-01  3.450570e-25  0.039671     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### GRU

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/my2_gru_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_GRU(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_GRU(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 7ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 7ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 8ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# Best Model Index: 0
# 35/35 [==============================] - 0s 2ms/step
# Test PRC Score: 0.032171581769437
# Test Balanced Accuracy Score: 0.5
# False Alarm Rate: 0.0
# Hit Rate: 0.0
# Best Model Path: Model/my2_gru_units_64_dropout_0.1_iteration_0.h5
# Confusion Matrix: [[1083    0]
#  [  36    0]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'GRU', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
df_2_5_base
# Out:
#   Model     Negara TP FP    TN  FN   HR   FR  BACC       PRC  \
# 0   RNN  Indonesia  0  0  1083  36  0.0  0.0   0.5  0.032172
# 1  LSTM  Indonesia  0  0  1083  36  0.0  0.0   0.5  0.032172
# 2   GRU  Indonesia  0  0  1083  36  0.0  0.0   0.5  0.032172
#
#                     Params
# 0  Units: 64, Dropout: 0.1
# 1  Units: 64, Dropout: 0.1
# 2  Units: 64, Dropout: 0.1

# %%
# Simpan prob untuk visualisasi
df_2_5_base_prob['ProbGRU'] = predictions_testprob
df_2_5_base_prob
# Out:
#                  ProbRNN  ProbLSTM       ProbGRU ProbRF ProbXGB
# 2020-01-08  4.436488e-25  0.040160  6.824100e-10    NaN     NaN
# 2020-01-09  4.268890e-25  0.040203  6.693590e-10    NaN     NaN
# 2020-01-10  4.374143e-25  0.040188  6.731539e-10    NaN     NaN
# 2020-01-13  4.096371e-25  0.040243  6.639879e-10    NaN     NaN
# 2020-01-14  4.083702e-25  0.040239  6.669644e-10    NaN     NaN
# ...                  ...       ...           ...    ...     ...
# 2023-10-26  3.407236e-25  0.039552  6.274556e-10    NaN     NaN
# 2023-10-27  3.361392e-25  0.039617  6.355546e-10    NaN     NaN
# 2023-10-30  3.432440e-25  0.039657  6.350274e-10    NaN     NaN
# 2023-10-31  3.388919e-25  0.039633  6.228744e-10    NaN     NaN
# 2023-11-01  3.450570e-25  0.039671  6.376272e-10    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ## Evaluation Smote

# %%
# Dataframe indonesia 2.5% nanti append tiap selesai pemodelan
# Ada kolom  - Model	Negara	TP	FP	TN	FN	HR	FR	BACC	PRC
df_2_5 = pd.DataFrame(columns=['Model', 'Negara', 'TP', 'FP', 'TN', 'FN', 'HR', 'FR', 'BACC', 'PRC', 'Params'])
df_2_5
# Out:
# Empty DataFrame
# Columns: [Model, Negara, TP, FP, TN, FN, HR, FR, BACC, PRC, Params]
# Index: []

# %%
# Simpan prob untuk visualisasi
df_2_5_prob = pd.DataFrame(columns=['ProbRNN','ProbLSTM', 'ProbGRU', 'ProbRF', 'ProbXGB'])
df_2_5_prob = pd.concat([df_2_5_prob, pd.DataFrame(index=y_test_lagged.index)])
df_2_5_prob
# Out:
# C:\Users\derik\AppData\Local\Temp\ipykernel_6048\477191898.py:3: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   df_2_5_prob = pd.concat([df_2_5_prob, pd.DataFrame(index=y_test_lagged.index)])
#            ProbRNN ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08     NaN      NaN     NaN    NaN     NaN
# 2020-01-09     NaN      NaN     NaN    NaN     NaN
# 2020-01-10     NaN      NaN     NaN    NaN     NaN
# 2020-01-13     NaN      NaN     NaN    NaN     NaN
# 2020-01-14     NaN      NaN     NaN    NaN     NaN
# ...            ...      ...     ...    ...     ...
# 2023-10-26     NaN      NaN     NaN    NaN     NaN
# 2023-10-27     NaN      NaN     NaN    NaN     NaN
# 2023-10-30     NaN      NaN     NaN    NaN     NaN
# 2023-10-31     NaN      NaN     NaN    NaN     NaN
# 2023-11-01     NaN      NaN     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### RNN

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/my2_rnn_smote_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_RNN(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_RNN(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 922us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 7ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 3ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 2s 5ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# Best Model Index: 26
# 35/35 [==============================] - 1s 4ms/step
# Test PRC Score: 0.0971477509681263
# Test Balanced Accuracy Score: 0.5671360418590335
# False Alarm Rate: 0.0046168051708217915
# Hit Rate: 0.1388888888888889
# Best Model Path: Model/my2_rnn_smote_units_128_dropout_0.1_iteration_6.h5
# Confusion Matrix: [[1078    5]
#  [  31    5]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'RNN', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
df_2_5
# Out:
# C:\Users\derik\AppData\Local\Temp\ipykernel_6048\3206386942.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
#   Model     Negara TP FP    TN  FN        HR        FR      BACC       PRC  \
# 0   RNN  Indonesia  5  5  1078  31  0.138889  0.004617  0.567136  0.097148
#
#                      Params
# 0  Units: 128, Dropout: 0.1

# %%
# Simpan prob untuk visualisasi
df_2_5_prob['ProbRNN'] = predictions_testprob
df_2_5_prob
# Out:
#              ProbRNN ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08  0.000308      NaN     NaN    NaN     NaN
# 2020-01-09  0.000251      NaN     NaN    NaN     NaN
# 2020-01-10  0.000410      NaN     NaN    NaN     NaN
# 2020-01-13  0.000984      NaN     NaN    NaN     NaN
# 2020-01-14  0.000675      NaN     NaN    NaN     NaN
# ...              ...      ...     ...    ...     ...
# 2023-10-26  0.005320      NaN     NaN    NaN     NaN
# 2023-10-27  0.006574      NaN     NaN    NaN     NaN
# 2023-10-30  0.005858      NaN     NaN    NaN     NaN
# 2023-10-31  0.005043      NaN     NaN    NaN     NaN
# 2023-11-01  0.004987      NaN     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### LSTM

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/my2_lstm_smote_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_LSTM(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_LSTM(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 7ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 7ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 8ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 8ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 9ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 7ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 7ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# Best Model Index: 6
# 35/35 [==============================] - 1s 5ms/step
# Test PRC Score: 0.11665673716612054
# Test Balanced Accuracy Score: 0.5935287780855648
# False Alarm Rate: 0.007386888273314866
# Hit Rate: 0.19444444444444445
# Best Model Path: Model/my2_lstm_smote_units_64_dropout_0.1_iteration_6.h5
# Confusion Matrix: [[1075    8]
#  [  29    7]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'LSTM', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
df_2_5
# Out:
#   Model     Negara TP FP    TN  FN        HR        FR      BACC       PRC  \
# 0   RNN  Indonesia  5  5  1078  31  0.138889  0.004617  0.567136  0.097148
# 1  LSTM  Indonesia  7  8  1075  29  0.194444  0.007387  0.593529  0.116657
#
#                      Params
# 0  Units: 128, Dropout: 0.1
# 1   Units: 64, Dropout: 0.1

# %%
# Simpan prob untuk visualisasi
df_2_5_prob['ProbLSTM'] = predictions_testprob
df_2_5_prob
# Out:
#              ProbRNN  ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08  0.000308  0.060038     NaN    NaN     NaN
# 2020-01-09  0.000251  0.085367     NaN    NaN     NaN
# 2020-01-10  0.000410  0.068650     NaN    NaN     NaN
# 2020-01-13  0.000984  0.075173     NaN    NaN     NaN
# 2020-01-14  0.000675  0.079117     NaN    NaN     NaN
# ...              ...       ...     ...    ...     ...
# 2023-10-26  0.005320  0.098352     NaN    NaN     NaN
# 2023-10-27  0.006574  0.116450     NaN    NaN     NaN
# 2023-10-30  0.005858  0.110819     NaN    NaN     NaN
# 2023-10-31  0.005043  0.120456     NaN    NaN     NaN
# 2023-11-01  0.004987  0.115913     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### GRU

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/my2_gru_smote_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_GRU(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_GRU(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 5ms/step
# 35/35 [==============================] - 0s 5ms/step
# 35/35 [==============================] - 2s 7ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 4ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 4ms/step
# 35/35 [==============================] - 1s 6ms/step
# 35/35 [==============================] - 0s 7ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 6ms/step
# 35/35 [==============================] - 1s 7ms/step
# 35/35 [==============================] - 0s 6ms/step
# Best Model Index: 33
# 35/35 [==============================] - 1s 7ms/step
# Test PRC Score: 0.11748585046172177
# Test Balanced Accuracy Score: 0.5550938750384734
# False Alarm Rate: 0.0009233610341643582
# Hit Rate: 0.1111111111111111
# Best Model Path: Model/my2_gru_smote_units_128_dropout_0.2_iteration_3.h5
# Confusion Matrix: [[1082    1]
#  [  32    4]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'GRU', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
df_2_5
# Out:
#   Model     Negara TP FP    TN  FN        HR        FR      BACC       PRC  \
# 0   RNN  Indonesia  5  5  1078  31  0.138889  0.004617  0.567136  0.097148
# 1  LSTM  Indonesia  7  8  1075  29  0.194444  0.007387  0.593529  0.116657
# 2   GRU  Indonesia  4  1  1082  32  0.111111  0.000923  0.555094  0.117486
#
#                      Params
# 0  Units: 128, Dropout: 0.1
# 1   Units: 64, Dropout: 0.1
# 2  Units: 128, Dropout: 0.2

# %%
# Simpan prob untuk visualisasi
df_2_5_prob['ProbGRU'] = predictions_testprob
df_2_5_prob
# Out:
#              ProbRNN  ProbLSTM   ProbGRU ProbRF ProbXGB
# 2020-01-08  0.000308  0.060038  0.000122    NaN     NaN
# 2020-01-09  0.000251  0.085367  0.000504    NaN     NaN
# 2020-01-10  0.000410  0.068650  0.000208    NaN     NaN
# 2020-01-13  0.000984  0.075173  0.000271    NaN     NaN
# 2020-01-14  0.000675  0.079117  0.000464    NaN     NaN
# ...              ...       ...       ...    ...     ...
# 2023-10-26  0.005320  0.098352  0.000348    NaN     NaN
# 2023-10-27  0.006574  0.116450  0.000765    NaN     NaN
# 2023-10-30  0.005858  0.110819  0.000454    NaN     NaN
# 2023-10-31  0.005043  0.120456  0.000754    NaN     NaN
# 2023-11-01  0.004987  0.115913  0.000613    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ## Evalution RF dan XGBoost

# %%
# Latih model pada periode train yang lebih besar
X_train_full = split_data(X, pd.Timestamp('2010-01-01'), pd.Timestamp('2019-12-31'))
y_train_full = split_data(y, pd.Timestamp('2010-01-01'), pd.Timestamp('2019-12-31'))

X_train_full_lagged = create_lagged_features(X_train_full, look_back)
y_train_full_lagged = y_train_full[look_back:]

# Uji model pada periode test
X_test = split_data(X, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))
y_test = split_data(y, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))

X_test_lagged = create_lagged_features(X_test, look_back)
y_test_lagged = y_test[look_back:]

# %% [markdown]
# ### RF

# %%
# Random forest
# Memuat best_params dari file
with open('Model/my2_rf.pkl', 'rb') as f:
    best_params = pickle.load(f)
model_final = RandomForestClassifier(**best_params, random_state=1501211036)
model_final.fit(X_train_full_lagged, y_train_full_lagged)
predictions_test = model_final.predict(X_test_lagged)
prc_score = average_precision_score(y_test_lagged, predictions_test)
print(f"Test PRC  Score: {prc_score}")
bacc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
print(f"Test Balance Accuracy  Score: {bacc_score}")
cm = confusion_matrix(y_test_lagged, predictions_test)
print(cm)
TP = cm[1, 1]
FN = cm[1, 0]
FP = cm[0, 1]
TN = cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)
print("False Alarm Rate:", FAR)
print("Hit Rate:", HR)

eval_rf = {
    'Metric': ['Test PRC Score', 'Test Balance Accuracy Score', 'False Alarm Rate', 'Hit Rate'],
    'Value': [prc_score, bacc_score, FAR, HR]
}
# Out:
# Test PRC  Score: 0.029618640238575775
# Test Balance Accuracy  Score: 0.4217451523545706
# [[733 350]
#  [ 30   6]]
# False Alarm Rate: 0.3231763619575254
# Hit Rate: 0.16666666666666666

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'RF', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': bacc_score, 
    'PRC': prc_score, 
    'Params': f"N Estimators: {best_params['n_estimators']}, Max Depth: {best_params['max_depth']}"
}])

# Menggabungkan dengan DataFrame sebelumnya
df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
df_2_5_base
# Out:
#   Model     Negara TP   FP    TN  FN        HR        FR      BACC       PRC  \
# 0   RNN  Indonesia  0    0  1083  36  0.000000  0.000000  0.500000  0.032172
# 1  LSTM  Indonesia  0    0  1083  36  0.000000  0.000000  0.500000  0.032172
# 2   GRU  Indonesia  0    0  1083  36  0.000000  0.000000  0.500000  0.032172
# 3    RF  Indonesia  6  350   733  30  0.166667  0.323176  0.421745  0.029619
#
#                              Params
# 0           Units: 64, Dropout: 0.1
# 1           Units: 64, Dropout: 0.1
# 2           Units: 64, Dropout: 0.1
# 3  N Estimators: 100, Max Depth: 10

# %% [markdown]
# ### XGB

# %%
# XGB
with open('Model/my2_xgb.pkl', 'rb') as f:
    best_params = pickle.load(f)

model_final = XGBClassifier(**best_params, use_label_encoder=False, eval_metric='logloss', random_state=1501211036)
model_final.fit(X_train_full_lagged, y_train_full_lagged)

predictions_test = model_final.predict(X_test_lagged)
prc_score = average_precision_score(y_test_lagged, predictions_test)
print(f"Test PRC  Score: {prc_score}")
bacc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
print(f"Test Balance Accuracy  Score: {bacc_score}")
cm = confusion_matrix(y_test_lagged, predictions_test)
print(cm)
TP = cm[1, 1]
FN = cm[1, 0]
FP = cm[0, 1]
TN = cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)
print("False Alarm Rate:", FAR)
print("Hit Rate:", HR)

eval_xgboost = {
    'Metric': ['Test PRC Score', 'Test Balance Accuracy Score', 'False Alarm Rate', 'Hit Rate'],
    'Value': [prc_score, bacc_score, FAR, HR]
}
# Out:
# Test PRC  Score: 0.032171581769437
# Test Balance Accuracy  Score: 0.5
# [[1083    0]
#  [  36    0]]
# False Alarm Rate: 0.0
# Hit Rate: 0.0

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'XGBoost', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': bacc_score, 
    'PRC': prc_score, 
    'Params': f"Learning Rate: {best_params['learning_rate']}, N Estimators: {best_params['n_estimators']}, Max Depth: {best_params['max_depth']}"
}])

# Menggabungkan dengan DataFrame sebelumnya
df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
df_2_5_base
# Out:
#      Model     Negara TP   FP    TN  FN        HR        FR      BACC  \
# 0      RNN  Indonesia  0    0  1083  36  0.000000  0.000000  0.500000
# 1     LSTM  Indonesia  0    0  1083  36  0.000000  0.000000  0.500000
# 2      GRU  Indonesia  0    0  1083  36  0.000000  0.000000  0.500000
# 3       RF  Indonesia  6  350   733  30  0.166667  0.323176  0.421745
# 4  XGBoost  Indonesia  0    0  1083  36  0.000000  0.000000  0.500000
#
#         PRC                                             Params
# 0  0.032172                            Units: 64, Dropout: 0.1
# 1  0.032172                            Units: 64, Dropout: 0.1
# 2  0.032172                            Units: 64, Dropout: 0.1
# 3  0.029619                   N Estimators: 100, Max Depth: 10
# 4  0.032172  Learning Rate: 0.1, N Estimators: 300, Max Dep...

# %% [markdown]
# ### RF SMOTE

# %%
# Latih model pada periode train yang lebih besar
X_train_full = split_data(X, pd.Timestamp('2010-01-01'), pd.Timestamp('2019-12-31'))
y_train_full = split_data(y, pd.Timestamp('2010-01-01'), pd.Timestamp('2019-12-31'))

# Handling imbalanced with smote
smote_enn = SMOTEENN(random_state=1501211036)
X_train_resampled, y_train_resampled = smote_enn.fit_resample(X_train_full, y_train_full)

X_train_full_lagged = create_lagged_features(X_train_resampled, look_back)
y_train_full_lagged = y_train_resampled[look_back:]

# Uji model pada periode test
X_test = split_data(X, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))
y_test = split_data(y, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))

X_test_lagged = create_lagged_features(X_test, look_back)
y_test_lagged = y_test[look_back:]

# %%
# Random forest
# Memuat best_params dari file
with open('Model/my2_rf_smote.pkl', 'rb') as f:
    best_params = pickle.load(f)
model_final = RandomForestClassifier(**best_params, random_state=1501211036)
model_final.fit(X_train_full_lagged, y_train_full_lagged)
predictions_test = model_final.predict(X_test_lagged)
prc_score = average_precision_score(y_test_lagged, predictions_test)
print(f"Test PRC  Score: {prc_score}")
bacc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
print(f"Test Balance Accuracy  Score: {bacc_score}")
cm = confusion_matrix(y_test_lagged, predictions_test)
print(cm)
TP = cm[1, 1]
FN = cm[1, 0]
FP = cm[0, 1]
TN = cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)
print("False Alarm Rate:", FAR)
print("Hit Rate:", HR)

eval_rf = {
    'Metric': ['Test PRC Score', 'Test Balance Accuracy Score', 'False Alarm Rate', 'Hit Rate'],
    'Value': [prc_score, bacc_score, FAR, HR]
}
# Out:
# Test PRC  Score: 0.03200892087233275
# Test Balance Accuracy  Score: 0.49680670975684826
# [[1046   37]
#  [  35    1]]
# False Alarm Rate: 0.034164358264081256
# Hit Rate: 0.027777777777777776

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'RF', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': bacc_score, 
    'PRC': prc_score, 
    'Params': f"N Estimators: {best_params['n_estimators']}, Max Depth: {best_params['max_depth']}"
}])

# Menggabungkan dengan DataFrame sebelumnya
df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
df_2_5
# Out:
#   Model     Negara TP  FP    TN  FN        HR        FR      BACC       PRC  \
# 0   RNN  Indonesia  5   5  1078  31  0.138889  0.004617  0.567136  0.097148
# 1  LSTM  Indonesia  7   8  1075  29  0.194444  0.007387  0.593529  0.116657
# 2   GRU  Indonesia  4   1  1082  32  0.111111  0.000923  0.555094  0.117486
# 3    RF  Indonesia  1  37  1046  35  0.027778  0.034164  0.496807  0.032009
#
#                              Params
# 0          Units: 128, Dropout: 0.1
# 1           Units: 64, Dropout: 0.1
# 2          Units: 128, Dropout: 0.2
# 3  N Estimators: 200, Max Depth: 20

# %% [markdown]
# ### XGB SMOTE

# %%
# XGB
with open('Model/my2_xgb_smote.pkl', 'rb') as f:
    best_params = pickle.load(f)

model_final = XGBClassifier(**best_params, use_label_encoder=False, eval_metric='logloss', random_state=1501211036)
model_final.fit(X_train_full_lagged, y_train_full_lagged)

predictions_test = model_final.predict(X_test_lagged)
prc_score = average_precision_score(y_test_lagged, predictions_test)
print(f"Test PRC  Score: {prc_score}")
bacc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
print(f"Test Balance Accuracy  Score: {bacc_score}")
cm = confusion_matrix(y_test_lagged, predictions_test)
print(cm)
TP = cm[1, 1]
FN = cm[1, 0]
FP = cm[0, 1]
TN = cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)
print("False Alarm Rate:", FAR)
print("Hit Rate:", HR)

eval_xgboost = {
    'Metric': ['Test PRC Score', 'Test Balance Accuracy Score', 'False Alarm Rate', 'Hit Rate'],
    'Value': [prc_score, bacc_score, FAR, HR]
}
# Out:
# Test PRC  Score: 0.05622141618041318
# Test Balance Accuracy  Score: 0.5704062788550324
# [[1055   28]
#  [  30    6]]
# False Alarm Rate: 0.02585410895660203
# Hit Rate: 0.16666666666666666

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'XGBoost', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': bacc_score, 
    'PRC': prc_score, 
    'Params': f"Learning Rate: {best_params['learning_rate']}, N Estimators: {best_params['n_estimators']}, Max Depth: {best_params['max_depth']}"
}])

# Menggabungkan dengan DataFrame sebelumnya
df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
df_2_5
# Out:
#      Model     Negara TP  FP    TN  FN        HR        FR      BACC  \
# 0      RNN  Indonesia  5   5  1078  31  0.138889  0.004617  0.567136
# 1     LSTM  Indonesia  7   8  1075  29  0.194444  0.007387  0.593529
# 2      GRU  Indonesia  4   1  1082  32  0.111111  0.000923  0.555094
# 3       RF  Indonesia  1  37  1046  35  0.027778  0.034164  0.496807
# 4  XGBoost  Indonesia  6  28  1055  30  0.166667  0.025854  0.570406
#
#         PRC                                             Params
# 0  0.097148                           Units: 128, Dropout: 0.1
# 1  0.116657                            Units: 64, Dropout: 0.1
# 2  0.117486                           Units: 128, Dropout: 0.2
# 3  0.032009                   N Estimators: 200, Max Depth: 20
# 4  0.056221  Learning Rate: 0.001, N Estimators: 100, Max D...

# %% [markdown]
# # Export

# %%
# Save to excel to folder Output
df_2_5_base.to_excel('Output/my2_base.xlsx', index=False)
df_2_5_base_prob.to_excel('Output/my2_base_prob.xlsx', index=True)
df_2_5.to_excel('Output/my2_smote.xlsx', index=False)
df_2_5_prob.to_excel('Output/my2_smote_prob.xlsx', index=True)

# %% [markdown]
# # Library

# %%
# Import standard data processing libraries
import pandas as pd
import numpy as np
import random
import os

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# Set log level
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tempfile
import warnings
from sklearn.exceptions import ConvergenceWarning
import pickle
import re

# Filter warnings
warnings.simplefilter('ignore', ConvergenceWarning)
warnings.filterwarnings('ignore', category=UserWarning, module='xgboost')

# Import visualization library
import matplotlib.pyplot as plt

# Import Machine Learning and Data Preprocessing libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import KNNImputer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import (precision_recall_curve, average_precision_score, 
                             confusion_matrix, accuracy_score, precision_score, 
                             recall_score, f1_score, balanced_accuracy_score)
from imblearn.combine import SMOTEENN
from sklearn.utils.class_weight import compute_class_weight

# Import Deep Learning libraries - Keras & TensorFlow
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import (Dense, Input, GlobalMaxPooling1D, LSTM, GRU, 
                                     Bidirectional, Dropout, BatchNormalization, SimpleRNN)
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.metrics import BinaryAccuracy, AUC
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.layers import Activation

# %% [markdown]
# # Functions

# %%
# Fungsi Setiap Arsiterktur
# Model GRU
def make_model_GRU(look_back, n_features, units, learning_rate, num_layers, dropout_rate=0.2):
    model = Sequential()
    # Menambahkan layer GRU
    for i in range(num_layers):
        return_sequences = i < num_layers - 1  # True untuk layer bukan terakhir
        model.add(GRU(
            units=units,
            activation='relu',
            input_shape=(look_back, n_features),
            return_sequences=return_sequences,
            kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            recurrent_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            bias_regularizer=l1_l2(l1=1e-5, l2=1e-4)
        ))
        model.add(Dropout(dropout_rate))

    # Menambahkan layer Dense
    model.add(Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))
    model.add(Dense(1, activation='sigmoid'))

    # Mengonfigurasi optimizer
    adam_optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam_optimizer, loss='binary_crossentropy', metrics=METRICS)
    return model

# Model LSTM
def make_model_LSTM(look_back, n_features, units, learning_rate, num_layers, dropout_rate=0.2):
    model = Sequential()
    # Menambahkan layer
    for i in range(num_layers):
        return_sequences = i < num_layers - 1  # True untuk layer bukan terakhir
        model.add(LSTM(
            units=units,
            activation='relu',
            input_shape=(look_back, n_features),
            return_sequences=return_sequences,
            kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            recurrent_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            bias_regularizer=l1_l2(l1=1e-5, l2=1e-4)
        ))
        model.add(Dropout(dropout_rate))

    # Menambahkan layer Dense
    model.add(Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))
    model.add(Dense(1, activation='sigmoid'))

    # Mengonfigurasi optimizer
    adam_optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam_optimizer, loss='binary_crossentropy', metrics=METRICS)
    return model

# Model RNN
def make_model_RNN(look_back, n_features, units, learning_rate, num_layers, dropout_rate=0.2):
    model = Sequential()
    # Menambahkan layer
    for i in range(num_layers):
        return_sequences = i < num_layers - 1  # True untuk layer bukan terakhir
        model.add(SimpleRNN(
            units=units,
            activation='relu',
            input_shape=(look_back, n_features),
            return_sequences=return_sequences,
            kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            recurrent_regularizer=l1_l2(l1=1e-5, l2=1e-4),
            bias_regularizer=l1_l2(l1=1e-5, l2=1e-4)
        ))
        model.add(Dropout(dropout_rate))

    # Menambahkan layer Dense
    model.add(Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))
    model.add(Dense(1, activation='sigmoid'))

    # Mengonfigurasi optimizer
    adam_optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam_optimizer, loss='binary_crossentropy', metrics=METRICS)
    return model

# Fungsi split data
def split_data(data, start, end):
    return data[(data.index >= start) & (data.index <= end)]

# Fungsi untuk mengubah fitur X menjadi format dengan lag untuk RNN, GRU, LSTM
def create_lagged_features_lstm(X, look_back):
    """
    Creates lagged features for LSTM, GRU, RNN
    
    Args:
    X (array-like): The input features.
    look_back (int): The number of lag days.

    Returns:
    numpy.array: Transformed features with lag.
    """
    X_lagged = []
    for i in range(look_back, len(X)):
        X_lagged.append(X[i-look_back:i, :])
    return np.array(X_lagged)

# Metrik PRC AUC
METRICS = [
    'accuracy',
    AUC(name='prc', curve='PR'),
]

# Time Steps
look_back = 5

# Fungsi untuk mengubah fitur X menjadi format dengan lag untuk random forest dan xgboost
def create_lagged_features(X, look_back):
    X_lagged = []
    for i in range(look_back, len(X)):
        # Convert the DataFrame slice to a NumPy array before flattening
        X_lagged.append(X.iloc[i-look_back:i].to_numpy().flatten())
    return np.array(X_lagged)

# Extrack nama path
def extract_params_from_path(model_path):
    match = re.search(r'units_(\d+)_dropout_([\d.]+)_iteration', model_path)
    if match:
        units = int(match.group(1))
        dropout_rate = float(match.group(2))
        return units, dropout_rate
    else:
        raise ValueError("Model path tidak sesuai dengan pola yang diharapkan")

# %% [markdown]
# # Data

# %%
# Data Loading
data = pd.read_excel('Data/df.filipina.5persen.xlsx', index_col=0)

# Data Normalization
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# Data Imputation with KNNImputer
imputer = KNNImputer(n_neighbors=5)  # You can change '5' to the desired number of neighbors
data_imputed = imputer.fit_transform(data_scaled)

# Converting imputed data back to DataFrame
data_imputed_df = pd.DataFrame(data_imputed, columns=data.columns, index=data.index)

# Binarize a specific column based on a threshold
# Here, replacing values in the second column based on a 0.5 threshold
data_imputed_df.iloc[:, 1:2] = (data_imputed_df.iloc[:, 1:2] >= 0.5).astype(int)

# Updating the scaled data
data_scaled = data_imputed_df

# Ensuring the index is of datetime type
data_scaled.index = pd.to_datetime(data_scaled.index)

# Extracting the year from the index and creating a 'year' column
data_scaled['year'] = data_scaled.index.year

# Calculating the binary classification proportion per year
proportion_per_year = data_scaled.groupby('year')['idn_crash'].value_counts(normalize=True).unstack()

# Separating the target variable (y) and features (X)
y = data_imputed_df['idn_crash']
X = data_imputed_df.drop('idn_crash', axis=1)

# Uji model pada periode test
X_test = split_data(X, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))
y_test = split_data(y, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))

X_test_lagged = create_lagged_features_lstm(X_test.to_numpy(), look_back)
y_test_lagged = y_test[look_back:]

# Menghitung jumlah fitur
n_features = X_test_lagged.shape[2]

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Evaluation Baseline

# %%
# Dataframe indonesia 2.5% nanti append tiap selesai pemodelan
# Ada kolom  - Model	Negara	TP	FP	TN	FN	HR	FR	BACC	PRC
df_2_5_base = pd.DataFrame(columns=['Model', 'Negara', 'TP', 'FP', 'TN', 'FN', 'HR', 'FR', 'BACC', 'PRC', 'Params'])
df_2_5_base
# Out:
# Empty DataFrame
# Columns: [Model, Negara, TP, FP, TN, FN, HR, FR, BACC, PRC, Params]
# Index: []

# %%
# Simpan prob untuk visualisasi
df_2_5_base_prob = pd.DataFrame(columns=['ProbRNN','ProbLSTM', 'ProbGRU', 'ProbRF', 'ProbXGB'])
df_2_5_base_prob = pd.concat([df_2_5_base_prob, pd.DataFrame(index=y_test_lagged.index)])
df_2_5_base_prob
# Out:
# C:\Users\derik\AppData\Local\Temp\ipykernel_34008\4288287188.py:3: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   df_2_5_base_prob = pd.concat([df_2_5_base_prob, pd.DataFrame(index=y_test_lagged.index)])
#            ProbRNN ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08     NaN      NaN     NaN    NaN     NaN
# 2020-01-09     NaN      NaN     NaN    NaN     NaN
# 2020-01-10     NaN      NaN     NaN    NaN     NaN
# 2020-01-13     NaN      NaN     NaN    NaN     NaN
# 2020-01-14     NaN      NaN     NaN    NaN     NaN
# ...            ...      ...     ...    ...     ...
# 2023-10-26     NaN      NaN     NaN    NaN     NaN
# 2023-10-27     NaN      NaN     NaN    NaN     NaN
# 2023-10-30     NaN      NaN     NaN    NaN     NaN
# 2023-10-31     NaN      NaN     NaN    NaN     NaN
# 2023-11-01     NaN      NaN     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### RNN

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/ph3_rnn_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_RNN(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_RNN(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 647us/step
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 559us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 824us/step
# 35/35 [==============================] - 0s 794us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 647us/step
# 35/35 [==============================] - 0s 676us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 676us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 647us/step
# 35/35 [==============================] - 0s 647us/step
# 35/35 [==============================] - 0s 765us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 647us/step
# 35/35 [==============================] - 0s 647us/step
# 35/35 [==============================] - 0s 588us/step
# 35/35 [==============================] - 0s 647us/step
# 35/35 [==============================] - 0s 647us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 740us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 605us/step
# 35/35 [==============================] - 0s 676us/step
# 35/35 [==============================] - 0s 618us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 676us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 706us/step
# 35/35 [==============================] - 0s 677us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 882us/step
# 35/35 [==============================] - 0s 735us/step
# 35/35 [==============================] - 0s 959us/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 959us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 1000us/step
# Best Model Index: 0
# 35/35 [==============================] - 0s 971us/step
# Test PRC Score: 0.05630026809651475
# Test Balanced Accuracy Score: 0.5
# False Alarm Rate: 0.0
# Hit Rate: 0.0
# Best Model Path: Model/ph3_rnn_units_64_dropout_0.1_iteration_0.h5
# Confusion Matrix: [[1056    0]
#  [  63    0]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'RNN', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
df_2_5_base
# Out:
# C:\Users\derik\AppData\Local\Temp\ipykernel_34008\1641053047.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
#   Model     Negara TP FP    TN  FN   HR   FR  BACC     PRC  \
# 0   RNN  Indonesia  0  0  1056  63  0.0  0.0   0.5  0.0563
#
#                     Params
# 0  Units: 64, Dropout: 0.1

# %%
# Simpan prob untuk visualisasi
df_2_5_base_prob['ProbRNN'] = predictions_testprob
df_2_5_base_prob
# Out:
#              ProbRNN ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08  0.059844      NaN     NaN    NaN     NaN
# 2020-01-09  0.059832      NaN     NaN    NaN     NaN
# 2020-01-10  0.059771      NaN     NaN    NaN     NaN
# 2020-01-13  0.059721      NaN     NaN    NaN     NaN
# 2020-01-14  0.059728      NaN     NaN    NaN     NaN
# ...              ...      ...     ...    ...     ...
# 2023-10-26  0.059177      NaN     NaN    NaN     NaN
# 2023-10-27  0.059246      NaN     NaN    NaN     NaN
# 2023-10-30  0.059258      NaN     NaN    NaN     NaN
# 2023-10-31  0.059170      NaN     NaN    NaN     NaN
# 2023-11-01  0.059163      NaN     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### LSTM

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/ph3_lstm_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_LSTM(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_LSTM(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# Best Model Index: 0
# 35/35 [==============================] - 0s 2ms/step
# Test PRC Score: 0.05630026809651475
# Test Balanced Accuracy Score: 0.5
# False Alarm Rate: 0.0
# Hit Rate: 0.0
# Best Model Path: Model/ph3_lstm_units_64_dropout_0.1_iteration_0.h5
# Confusion Matrix: [[1056    0]
#  [  63    0]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'LSTM', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
df_2_5_base
# Out:
#   Model     Negara TP FP    TN  FN   HR   FR  BACC     PRC  \
# 0   RNN  Indonesia  0  0  1056  63  0.0  0.0   0.5  0.0563
# 1  LSTM  Indonesia  0  0  1056  63  0.0  0.0   0.5  0.0563
#
#                     Params
# 0  Units: 64, Dropout: 0.1
# 1  Units: 64, Dropout: 0.1

# %%
# Simpan prob untuk visualisasi
df_2_5_base_prob['ProbLSTM'] = predictions_testprob
df_2_5_base_prob
# Out:
#              ProbRNN  ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08  0.059844  0.004200     NaN    NaN     NaN
# 2020-01-09  0.059832  0.004175     NaN    NaN     NaN
# 2020-01-10  0.059771  0.004187     NaN    NaN     NaN
# 2020-01-13  0.059721  0.004223     NaN    NaN     NaN
# 2020-01-14  0.059728  0.004223     NaN    NaN     NaN
# ...              ...       ...     ...    ...     ...
# 2023-10-26  0.059177  0.003659     NaN    NaN     NaN
# 2023-10-27  0.059246  0.003666     NaN    NaN     NaN
# 2023-10-30  0.059258  0.003691     NaN    NaN     NaN
# 2023-10-31  0.059170  0.003718     NaN    NaN     NaN
# 2023-11-01  0.059163  0.003742     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### GRU

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/ph3_gru_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_GRU(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_GRU(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 1s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# Best Model Index: 0
# 35/35 [==============================] - 0s 1ms/step
# Test PRC Score: 0.05630026809651475
# Test Balanced Accuracy Score: 0.5
# False Alarm Rate: 0.0
# Hit Rate: 0.0
# Best Model Path: Model/ph3_gru_units_64_dropout_0.1_iteration_0.h5
# Confusion Matrix: [[1056    0]
#  [  63    0]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'GRU', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
df_2_5_base
# Out:
#   Model     Negara TP FP    TN  FN   HR   FR  BACC     PRC  \
# 0   RNN  Indonesia  0  0  1056  63  0.0  0.0   0.5  0.0563
# 1  LSTM  Indonesia  0  0  1056  63  0.0  0.0   0.5  0.0563
# 2   GRU  Indonesia  0  0  1056  63  0.0  0.0   0.5  0.0563
#
#                     Params
# 0  Units: 64, Dropout: 0.1
# 1  Units: 64, Dropout: 0.1
# 2  Units: 64, Dropout: 0.1

# %%
# Simpan prob untuk visualisasi
df_2_5_base_prob['ProbGRU'] = predictions_testprob
df_2_5_base_prob
# Out:
#              ProbRNN  ProbLSTM   ProbGRU ProbRF ProbXGB
# 2020-01-08  0.059844  0.004200  0.115052    NaN     NaN
# 2020-01-09  0.059832  0.004175  0.114620    NaN     NaN
# 2020-01-10  0.059771  0.004187  0.115002    NaN     NaN
# 2020-01-13  0.059721  0.004223  0.114983    NaN     NaN
# 2020-01-14  0.059728  0.004223  0.114981    NaN     NaN
# ...              ...       ...       ...    ...     ...
# 2023-10-26  0.059177  0.003659  0.113314    NaN     NaN
# 2023-10-27  0.059246  0.003666  0.113347    NaN     NaN
# 2023-10-30  0.059258  0.003691  0.113817    NaN     NaN
# 2023-10-31  0.059170  0.003718  0.113263    NaN     NaN
# 2023-11-01  0.059163  0.003742  0.113331    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ## Evaluation Smote

# %%
# Dataframe indonesia 2.5% nanti append tiap selesai pemodelan
# Ada kolom  - Model	Negara	TP	FP	TN	FN	HR	FR	BACC	PRC
df_2_5 = pd.DataFrame(columns=['Model', 'Negara', 'TP', 'FP', 'TN', 'FN', 'HR', 'FR', 'BACC', 'PRC', 'Params'])
df_2_5
# Out:
# Empty DataFrame
# Columns: [Model, Negara, TP, FP, TN, FN, HR, FR, BACC, PRC, Params]
# Index: []

# %%
# Simpan prob untuk visualisasi
df_2_5_prob = pd.DataFrame(columns=['ProbRNN','ProbLSTM', 'ProbGRU', 'ProbRF', 'ProbXGB'])
df_2_5_prob = pd.concat([df_2_5_prob, pd.DataFrame(index=y_test_lagged.index)])
df_2_5_prob
# Out:
# C:\Users\derik\AppData\Local\Temp\ipykernel_34008\477191898.py:3: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   df_2_5_prob = pd.concat([df_2_5_prob, pd.DataFrame(index=y_test_lagged.index)])
#            ProbRNN ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08     NaN      NaN     NaN    NaN     NaN
# 2020-01-09     NaN      NaN     NaN    NaN     NaN
# 2020-01-10     NaN      NaN     NaN    NaN     NaN
# 2020-01-13     NaN      NaN     NaN    NaN     NaN
# 2020-01-14     NaN      NaN     NaN    NaN     NaN
# ...            ...      ...     ...    ...     ...
# 2023-10-26     NaN      NaN     NaN    NaN     NaN
# 2023-10-27     NaN      NaN     NaN    NaN     NaN
# 2023-10-30     NaN      NaN     NaN    NaN     NaN
# 2023-10-31     NaN      NaN     NaN    NaN     NaN
# 2023-11-01     NaN      NaN     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### RNN

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/ph3_rnn_smote_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_RNN(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_RNN(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 912us/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 941us/step
# 35/35 [==============================] - 0s 1000us/step
# 35/35 [==============================] - 0s 971us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 913us/step
# 35/35 [==============================] - 0s 916us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 978us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 886us/step
# 35/35 [==============================] - 0s 918us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 927us/step
# 35/35 [==============================] - 0s 937us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 994us/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# Best Model Index: 0
# 35/35 [==============================] - 0s 972us/step
# Test PRC Score: 0.07855045503456073
# Test Balanced Accuracy Score: 0.6237824675324675
# False Alarm Rate: 0.32386363636363635
# Hit Rate: 0.5714285714285714
# Best Model Path: Model/ph3_rnn_smote_units_64_dropout_0.1_iteration_0.h5
# Confusion Matrix: [[714 342]
#  [ 27  36]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'RNN', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
df_2_5
# Out:
# C:\Users\derik\AppData\Local\Temp\ipykernel_34008\3206386942.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
#   Model     Negara  TP   FP   TN  FN        HR        FR      BACC      PRC  \
# 0   RNN  Indonesia  36  342  714  27  0.571429  0.323864  0.623782  0.07855
#
#                     Params
# 0  Units: 64, Dropout: 0.1

# %%
# Simpan prob untuk visualisasi
df_2_5_prob['ProbRNN'] = predictions_testprob
df_2_5_prob
# Out:
#              ProbRNN ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08  0.499321      NaN     NaN    NaN     NaN
# 2020-01-09  0.499578      NaN     NaN    NaN     NaN
# 2020-01-10  0.499794      NaN     NaN    NaN     NaN
# 2020-01-13  0.500002      NaN     NaN    NaN     NaN
# 2020-01-14  0.499861      NaN     NaN    NaN     NaN
# ...              ...      ...     ...    ...     ...
# 2023-10-26  0.500576      NaN     NaN    NaN     NaN
# 2023-10-27  0.500608      NaN     NaN    NaN     NaN
# 2023-10-30  0.500948      NaN     NaN    NaN     NaN
# 2023-10-31  0.501167      NaN     NaN    NaN     NaN
# 2023-11-01  0.501222      NaN     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### LSTM

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/ph3_lstm_smote_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_LSTM(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_LSTM(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 1s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 3ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# Best Model Index: 30
# 35/35 [==============================] - 0s 2ms/step
# Test PRC Score: 0.07478319746129014
# Test Balanced Accuracy Score: 0.5731195887445888
# False Alarm Rate: 0.09185606060606061
# Hit Rate: 0.23809523809523808
# Best Model Path: Model/ph3_lstm_smote_units_128_dropout_0.2_iteration_0.h5
# Confusion Matrix: [[959  97]
#  [ 48  15]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'LSTM', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
df_2_5
# Out:
#   Model     Negara  TP   FP   TN  FN        HR        FR      BACC       PRC  \
# 0   RNN  Indonesia  36  342  714  27  0.571429  0.323864  0.623782  0.078550
# 1  LSTM  Indonesia  15   97  959  48  0.238095  0.091856  0.573120  0.074783
#
#                      Params
# 0   Units: 64, Dropout: 0.1
# 1  Units: 128, Dropout: 0.2

# %%
# Simpan prob untuk visualisasi
df_2_5_prob['ProbLSTM'] = predictions_testprob
df_2_5_prob
# Out:
#              ProbRNN  ProbLSTM ProbGRU ProbRF ProbXGB
# 2020-01-08  0.499321  0.477446     NaN    NaN     NaN
# 2020-01-09  0.499578  0.477285     NaN    NaN     NaN
# 2020-01-10  0.499794  0.476662     NaN    NaN     NaN
# 2020-01-13  0.500002  0.478202     NaN    NaN     NaN
# 2020-01-14  0.499861  0.477939     NaN    NaN     NaN
# ...              ...       ...     ...    ...     ...
# 2023-10-26  0.500576  0.471311     NaN    NaN     NaN
# 2023-10-27  0.500608  0.472005     NaN    NaN     NaN
# 2023-10-30  0.500948  0.472106     NaN    NaN     NaN
# 2023-10-31  0.501167  0.473125     NaN    NaN     NaN
# 2023-11-01  0.501222  0.472825     NaN    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ### GRU

# %%
model_paths = []

for units in [64, 128]:
    for dropout_rate in [0.1, 0.2]:
        for i in range(10):  # 10 iterasi untuk setiap konfigurasi
            model_path = f'Model/ph3_gru_smote_units_{units}_dropout_{dropout_rate}_iteration_{i}.h5'
            model_paths.append(model_path)
best_score = 0
best_model_index = -1
results = []

for model_index in range(len(model_paths)):
    units, dropout_rate = extract_params_from_path(model_paths[model_index])
    model = make_model_GRU(look_back=look_back, n_features=n_features, units=units, 
                           learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
    model.load_weights(model_paths[model_index])
    
    predictions_test = model.predict(X_test_lagged)
    predictions_test_prob = model.predict(X_test_lagged)
    predictions_test = (predictions_test > 0.5).astype(int)
    
    prc_score = average_precision_score(y_test_lagged, predictions_test)
    balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
    cm = confusion_matrix(y_test_lagged, predictions_test)
    TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
    FAR = FP / (FP + TN)
    HR = TP / (TP + FN)
    
    results.append((model_index, prc_score, balanced_acc_score, FAR, HR))
    
    # Periksa apakah ini adalah model terbaik
    if prc_score > best_score:
        best_score = prc_score
        best_model_index = model_index

# Cetak hasil untuk model terbaik
print(f"Best Model Index: {best_model_index}")
units, dropout_rate = extract_params_from_path(model_paths[best_model_index])
best_model = make_model_GRU(look_back=look_back, n_features=n_features, units=units, 
                            learning_rate=0.001, num_layers=1, dropout_rate=dropout_rate)
best_model.load_weights(model_paths[best_model_index])

predictions_test = best_model.predict(X_test_lagged)
predictions_testprob = predictions_test
predictions_test = (predictions_test > 0.5).astype(int)

prc_score = average_precision_score(y_test_lagged, predictions_test)
balanced_acc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
cm = confusion_matrix(y_test_lagged, predictions_test)
TP, FN, FP, TN = cm[1, 1], cm[1, 0], cm[0, 1], cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)

print(f"Test PRC Score: {prc_score}")
print(f"Test Balanced Accuracy Score: {balanced_acc_score}")
print(f"False Alarm Rate: {FAR}")
print(f"Hit Rate: {HR}")
print(f"Best Model Path: {model_paths[best_model_index]}")
print(f"Confusion Matrix: {cm}")
# Out:
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 1s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 1ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# 35/35 [==============================] - 0s 2ms/step
# Best Model Index: 33
# 35/35 [==============================] - 0s 2ms/step
# Test PRC Score: 0.08715169912667678
# Test Balanced Accuracy Score: 0.5919462481962482
# False Alarm Rate: 0.07007575757575757
# Hit Rate: 0.25396825396825395
# Best Model Path: Model/ph3_gru_smote_units_128_dropout_0.2_iteration_3.h5
# Confusion Matrix: [[982  74]
#  [ 47  16]]

# %%
# Memuat histories
model_path_without_ext = model_paths[best_model_index].replace('.h5', '')
history_path = f'{model_path_without_ext}_history.pkl'
with open(history_path, 'rb') as file:
    loaded_history = pickle.load(file)

plt.figure(figsize=(12, 8))
plt.plot(loaded_history['loss'], label='Training Loss', linestyle='--')
plt.plot(loaded_history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'GRU', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': balanced_acc_score, 
    'PRC': prc_score, 
    'Params': f'Units: {units}, Dropout: {dropout_rate}'
}])
df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
df_2_5
# Out:
#   Model     Negara  TP   FP   TN  FN        HR        FR      BACC       PRC  \
# 0   RNN  Indonesia  36  342  714  27  0.571429  0.323864  0.623782  0.078550
# 1  LSTM  Indonesia  15   97  959  48  0.238095  0.091856  0.573120  0.074783
# 2   GRU  Indonesia  16   74  982  47  0.253968  0.070076  0.591946  0.087152
#
#                      Params
# 0   Units: 64, Dropout: 0.1
# 1  Units: 128, Dropout: 0.2
# 2  Units: 128, Dropout: 0.2

# %%
# Simpan prob untuk visualisasi
df_2_5_prob['ProbGRU'] = predictions_testprob
df_2_5_prob
# Out:
#              ProbRNN  ProbLSTM   ProbGRU ProbRF ProbXGB
# 2020-01-08  0.499321  0.477446  0.484180    NaN     NaN
# 2020-01-09  0.499578  0.477285  0.488283    NaN     NaN
# 2020-01-10  0.499794  0.476662  0.484498    NaN     NaN
# 2020-01-13  0.500002  0.478202  0.486428    NaN     NaN
# 2020-01-14  0.499861  0.477939  0.485474    NaN     NaN
# ...              ...       ...       ...    ...     ...
# 2023-10-26  0.500576  0.471311  0.482603    NaN     NaN
# 2023-10-27  0.500608  0.472005  0.485997    NaN     NaN
# 2023-10-30  0.500948  0.472106  0.486181    NaN     NaN
# 2023-10-31  0.501167  0.473125  0.486779    NaN     NaN
# 2023-11-01  0.501222  0.472825  0.486356    NaN     NaN
#
# [1119 rows x 5 columns]

# %% [markdown]
# ## Evalution RF dan XGBoost

# %%
# Latih model pada periode train yang lebih besar
X_train_full = split_data(X, pd.Timestamp('2010-01-01'), pd.Timestamp('2019-12-31'))
y_train_full = split_data(y, pd.Timestamp('2010-01-01'), pd.Timestamp('2019-12-31'))

X_train_full_lagged = create_lagged_features(X_train_full, look_back)
y_train_full_lagged = y_train_full[look_back:]

# Uji model pada periode test
X_test = split_data(X, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))
y_test = split_data(y, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))

X_test_lagged = create_lagged_features(X_test, look_back)
y_test_lagged = y_test[look_back:]

# %% [markdown]
# ### RF

# %%
# Random forest
# Memuat best_params dari file
with open('Model/ph3_rf.pkl', 'rb') as f:
    best_params = pickle.load(f)
model_final = RandomForestClassifier(**best_params, random_state=1501211036)
model_final.fit(X_train_full_lagged, y_train_full_lagged)
predictions_test = model_final.predict(X_test_lagged)
prc_score = average_precision_score(y_test_lagged, predictions_test)
print(f"Test PRC  Score: {prc_score}")
bacc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
print(f"Test Balance Accuracy  Score: {bacc_score}")
cm = confusion_matrix(y_test_lagged, predictions_test)
print(cm)
TP = cm[1, 1]
FN = cm[1, 0]
FP = cm[0, 1]
TN = cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)
print("False Alarm Rate:", FAR)
print("Hit Rate:", HR)

eval_rf = {
    'Metric': ['Test PRC Score', 'Test Balance Accuracy Score', 'False Alarm Rate', 'Hit Rate'],
    'Value': [prc_score, bacc_score, FAR, HR]
}
# Out:
# Test PRC  Score: 0.05464228099233845
# Test Balance Accuracy  Score: 0.4830898268398268
# [[618 438]
#  [ 39  24]]
# False Alarm Rate: 0.4147727272727273
# Hit Rate: 0.38095238095238093

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'RF', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': bacc_score, 
    'PRC': prc_score, 
    'Params': f"N Estimators: {best_params['n_estimators']}, Max Depth: {best_params['max_depth']}"
}])

# Menggabungkan dengan DataFrame sebelumnya
df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
df_2_5_base
# Out:
#   Model     Negara  TP   FP    TN  FN        HR        FR     BACC       PRC  \
# 0   RNN  Indonesia   0    0  1056  63  0.000000  0.000000  0.50000  0.056300
# 1  LSTM  Indonesia   0    0  1056  63  0.000000  0.000000  0.50000  0.056300
# 2   GRU  Indonesia   0    0  1056  63  0.000000  0.000000  0.50000  0.056300
# 3    RF  Indonesia  24  438   618  39  0.380952  0.414773  0.48309  0.054642
#
#                              Params
# 0           Units: 64, Dropout: 0.1
# 1           Units: 64, Dropout: 0.1
# 2           Units: 64, Dropout: 0.1
# 3  N Estimators: 100, Max Depth: 20

# %% [markdown]
# ### XGB

# %%
# XGB
with open('Model/ph3_xgb.pkl', 'rb') as f:
    best_params = pickle.load(f)

model_final = XGBClassifier(**best_params, use_label_encoder=False, eval_metric='logloss', random_state=1501211036)
model_final.fit(X_train_full_lagged, y_train_full_lagged)

predictions_test = model_final.predict(X_test_lagged)
prc_score = average_precision_score(y_test_lagged, predictions_test)
print(f"Test PRC  Score: {prc_score}")
bacc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
print(f"Test Balance Accuracy  Score: {bacc_score}")
cm = confusion_matrix(y_test_lagged, predictions_test)
print(cm)
TP = cm[1, 1]
FN = cm[1, 0]
FP = cm[0, 1]
TN = cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)
print("False Alarm Rate:", FAR)
print("Hit Rate:", HR)

eval_xgboost = {
    'Metric': ['Test PRC Score', 'Test Balance Accuracy Score', 'False Alarm Rate', 'Hit Rate'],
    'Value': [prc_score, bacc_score, FAR, HR]
}
# Out:
# Test PRC  Score: 0.05630026809651475
# Test Balance Accuracy  Score: 0.49857954545454547
# [[1053    3]
#  [  63    0]]
# False Alarm Rate: 0.002840909090909091
# Hit Rate: 0.0

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'XGBoost', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': bacc_score, 
    'PRC': prc_score, 
    'Params': f"Learning Rate: {best_params['learning_rate']}, N Estimators: {best_params['n_estimators']}, Max Depth: {best_params['max_depth']}"
}])

# Menggabungkan dengan DataFrame sebelumnya
df_2_5_base = pd.concat([df_2_5_base, new_row], ignore_index=True)
df_2_5_base
# Out:
#      Model     Negara  TP   FP    TN  FN        HR        FR     BACC  \
# 0      RNN  Indonesia   0    0  1056  63  0.000000  0.000000  0.50000
# 1     LSTM  Indonesia   0    0  1056  63  0.000000  0.000000  0.50000
# 2      GRU  Indonesia   0    0  1056  63  0.000000  0.000000  0.50000
# 3       RF  Indonesia  24  438   618  39  0.380952  0.414773  0.48309
# 4  XGBoost  Indonesia   0    3  1053  63  0.000000  0.002841  0.49858
#
#         PRC                                             Params
# 0  0.056300                            Units: 64, Dropout: 0.1
# 1  0.056300                            Units: 64, Dropout: 0.1
# 2  0.056300                            Units: 64, Dropout: 0.1
# 3  0.054642                   N Estimators: 100, Max Depth: 20
# 4  0.056300  Learning Rate: 0.2, N Estimators: 200, Max Dep...

# %% [markdown]
# ### RF SMOTE

# %%
# Latih model pada periode train yang lebih besar
X_train_full = split_data(X, pd.Timestamp('2010-01-01'), pd.Timestamp('2019-12-31'))
y_train_full = split_data(y, pd.Timestamp('2010-01-01'), pd.Timestamp('2019-12-31'))

# Handling imbalanced with smote
smote_enn = SMOTEENN(random_state=1501211036)
X_train_resampled, y_train_resampled = smote_enn.fit_resample(X_train_full, y_train_full)

X_train_full_lagged = create_lagged_features(X_train_resampled, look_back)
y_train_full_lagged = y_train_resampled[look_back:]

# Uji model pada periode test
X_test = split_data(X, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))
y_test = split_data(y, pd.Timestamp('2020-01-01'), pd.Timestamp('2023-11-01'))

X_test_lagged = create_lagged_features(X_test, look_back)
y_test_lagged = y_test[look_back:]

# %%
# Random forest
# Memuat best_params dari file
with open('Model/ph3_rf_smote.pkl', 'rb') as f:
    best_params = pickle.load(f)
model_final = RandomForestClassifier(**best_params, random_state=1501211036)
model_final.fit(X_train_full_lagged, y_train_full_lagged)
predictions_test = model_final.predict(X_test_lagged)
prc_score = average_precision_score(y_test_lagged, predictions_test)
print(f"Test PRC  Score: {prc_score}")
bacc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
print(f"Test Balance Accuracy  Score: {bacc_score}")
cm = confusion_matrix(y_test_lagged, predictions_test)
print(cm)
TP = cm[1, 1]
FN = cm[1, 0]
FP = cm[0, 1]
TN = cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)
print("False Alarm Rate:", FAR)
print("Hit Rate:", HR)

eval_rf = {
    'Metric': ['Test PRC Score', 'Test Balance Accuracy Score', 'False Alarm Rate', 'Hit Rate'],
    'Value': [prc_score, bacc_score, FAR, HR]
}
# Out:
# Test PRC  Score: 0.06042202403749704
# Test Balance Accuracy  Score: 0.5152867965367965
# [[1038   18]
#  [  60    3]]
# False Alarm Rate: 0.017045454545454544
# Hit Rate: 0.047619047619047616

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'RF', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': bacc_score, 
    'PRC': prc_score, 
    'Params': f"N Estimators: {best_params['n_estimators']}, Max Depth: {best_params['max_depth']}"
}])

# Menggabungkan dengan DataFrame sebelumnya
df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
df_2_5
# Out:
#   Model     Negara  TP   FP    TN  FN        HR        FR      BACC       PRC  \
# 0   RNN  Indonesia  36  342   714  27  0.571429  0.323864  0.623782  0.078550
# 1  LSTM  Indonesia  15   97   959  48  0.238095  0.091856  0.573120  0.074783
# 2   GRU  Indonesia  16   74   982  47  0.253968  0.070076  0.591946  0.087152
# 3    RF  Indonesia   3   18  1038  60  0.047619  0.017045  0.515287  0.060422
#
#                              Params
# 0           Units: 64, Dropout: 0.1
# 1          Units: 128, Dropout: 0.2
# 2          Units: 128, Dropout: 0.2
# 3  N Estimators: 300, Max Depth: 20

# %% [markdown]
# ### XGB SMOTE

# %%
# XGB
with open('Model/ph3_xgb_smote.pkl', 'rb') as f:
    best_params = pickle.load(f)

model_final = XGBClassifier(**best_params, use_label_encoder=False, eval_metric='logloss', random_state=1501211036)
model_final.fit(X_train_full_lagged, y_train_full_lagged)

predictions_test = model_final.predict(X_test_lagged)
prc_score = average_precision_score(y_test_lagged, predictions_test)
print(f"Test PRC  Score: {prc_score}")
bacc_score = balanced_accuracy_score(y_test_lagged, predictions_test)
print(f"Test Balance Accuracy  Score: {bacc_score}")
cm = confusion_matrix(y_test_lagged, predictions_test)
print(cm)
TP = cm[1, 1]
FN = cm[1, 0]
FP = cm[0, 1]
TN = cm[0, 0]
FAR = FP / (FP + TN)
HR = TP / (TP + FN)
print("False Alarm Rate:", FAR)
print("Hit Rate:", HR)

eval_xgboost = {
    'Metric': ['Test PRC Score', 'Test Balance Accuracy Score', 'False Alarm Rate', 'Hit Rate'],
    'Value': [prc_score, bacc_score, FAR, HR]
}
# Out:
# Test PRC  Score: 0.0556221785510231
# Test Balance Accuracy  Score: 0.4926948051948052
# [[940 116]
#  [ 57   6]]
# False Alarm Rate: 0.10984848484848485
# Hit Rate: 0.09523809523809523

# %%
# Menyimpan hasil evaluasi ke dalam DataFrame
new_row = pd.DataFrame([{
    'Model': 'XGBoost', 
    'Negara': 'Indonesia', 
    'TP': TP, 
    'FP': FP, 
    'TN': TN, 
    'FN': FN, 
    'HR': HR, 
    'FR': FAR, 
    'BACC': bacc_score, 
    'PRC': prc_score, 
    'Params': f"Learning Rate: {best_params['learning_rate']}, N Estimators: {best_params['n_estimators']}, Max Depth: {best_params['max_depth']}"
}])

# Menggabungkan dengan DataFrame sebelumnya
df_2_5 = pd.concat([df_2_5, new_row], ignore_index=True)
df_2_5
# Out:
#      Model     Negara  TP   FP    TN  FN        HR        FR      BACC  \
# 0      RNN  Indonesia  36  342   714  27  0.571429  0.323864  0.623782
# 1     LSTM  Indonesia  15   97   959  48  0.238095  0.091856  0.573120
# 2      GRU  Indonesia  16   74   982  47  0.253968  0.070076  0.591946
# 3       RF  Indonesia   3   18  1038  60  0.047619  0.017045  0.515287
# 4  XGBoost  Indonesia   6  116   940  57  0.095238  0.109848  0.492695
#
#         PRC                                             Params
# 0  0.078550                            Units: 64, Dropout: 0.1
# 1  0.074783                           Units: 128, Dropout: 0.2
# 2  0.087152                           Units: 128, Dropout: 0.2
# 3  0.060422                   N Estimators: 300, Max Depth: 20
# 4  0.055622  Learning Rate: 0.001, N Estimators: 100, Max D...

# %% [markdown]
# # Export

# %%
# Save to excel to folder Output
df_2_5_base.to_excel('Output/ph3_base.xlsx', index=False)
df_2_5_base_prob.to_excel('Output/ph3_base_prob.xlsx', index=True)
df_2_5.to_excel('Output/ph3_smote.xlsx', index=False)
df_2_5_prob.to_excel('Output/ph3_smote_prob.xlsx', index=True)
